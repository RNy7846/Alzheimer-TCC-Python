# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
# !pip install visualkeras

# %%
# !pip install tensorflow_addons

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import tensorflow as tf
import matplotlib.pyplot as plt
import sklearn
import os
from distutils.dir_util import copy_tree, remove_tree

from PIL import Image
from random import randint

from imblearn.over_sampling import SMOTE

from sklearn.model_selection import train_test_split
from sklearn.metrics import matthews_corrcoef as MCC
from sklearn.metrics import balanced_accuracy_score as BAS
from sklearn.metrics import classification_report, confusion_matrix

import tensorflow_addons as tfa
from keras.preprocessing.image import ImageDataGenerator
from keras.utils.vis_utils import plot_model
from keras import Sequential, Input
from keras.layers import Dense, Dropout, Conv2D, Flatten, SeparableConv2D, BatchNormalization, GlobalAveragePooling2D, Activation
from keras.callbacks import ReduceLROnPlateau
from keras.models import Sequential, Model
from keras.applications.vgg19 import VGG19
from keras.preprocessing.image import ImageDataGenerator as IDG

import tensorflow.keras.backend as K

import visualkeras

# %% [markdown]
# TRATAMENTO DE DADOS

# %%
base_dir = "/content/drive/MyDrive/Colab Notebooks/Alzheimer_s Dataset/"
root_dir = "./"
test_dir = base_dir + "test/"
train_dir = base_dir + "train/"
work_dir = root_dir + "dataset/"

if os.path.exists(work_dir):
    remove_tree(work_dir)
    

os.mkdir(work_dir)
copy_tree(train_dir, work_dir)
copy_tree(test_dir, work_dir)
print("Conteudo diretorios:", os.listdir(work_dir))

# %%
WORK_DIR = './dataset/'

CLASSES = [ 'NonDemented',
            'VeryMildDemented',
            'MildDemented',
            'ModerateDemented']

IMG_SIZE = 176
IMAGE_SIZE = [176, 176]
DIM = (IMG_SIZE, IMG_SIZE)

# %%
#Executando o aumento de imagem para ter mais amostras de dados
ZOOM = [.99, 1.01]
BRIGHT_RANGE = [0.8, 1.2]
HORZ_FLIP = True
FILL_MODE = "constant"
DATA_FORMAT = "channels_last"

work_dr = IDG(rescale = 1./255, brightness_range=BRIGHT_RANGE, zoom_range=ZOOM, data_format=DATA_FORMAT, fill_mode=FILL_MODE, horizontal_flip=HORZ_FLIP)

train_data_gen = work_dr.flow_from_directory(directory=WORK_DIR, target_size=DIM, batch_size=6500, shuffle=False)

# %%
def show_images(generator,y_pred=None):
    
    # obter labels de imagem
    labels =dict(zip([0,1,2,3], CLASSES))
    
    # obter um lote de imagens
    x,y = generator.next()
    
    # gera grade de 9 imagens
    plt.figure(figsize=(10, 10))
    if y_pred is None:
        for i in range(9):
            ax = plt.subplot(3, 3, i + 1)
            idx = randint(0, 6400)
            plt.imshow(x[idx])
            plt.axis("off")
            plt.title("Classe:{}".format(labels[np.argmax(y[idx])]))
                                                     
    else:
        for i in range(9):
            ax = plt.subplot(3, 3, i + 1)
            plt.imshow(x[i])
            plt.axis("off")
            plt.title("Actual:{} \nPredicted:{}".format(labels[np.argmax(y[i])],labels[y_pred[i]]))
    

show_images(train_data_gen)

# %%
# Recuperando os dados do iterador ImageDataGenerator
train_data, train_labels = train_data_gen.next()
# Conhecendo as dimensões do nosso conjunto de dados
print(train_data.shape, train_labels.shape)

# %%
oversample = SMOTE()

train_data = train_data.reshape(-1, IMG_SIZE * IMG_SIZE * 3)

# %%
train_data.shape

# %%
#train_data, train_labels = oversample.fit_resample(train_data, train_labels)

# %%
train_data = train_data.reshape(-1, IMG_SIZE, IMG_SIZE, 3)

print(train_data.shape, train_labels.shape)

# %% [markdown]
# DIVISÃO TREINO E TESTE

# %%
#Dividindo os dados em conjuntos de treinamento, teste e validação

train_data, test_data, train_labels, test_labels = train_test_split(train_data, train_labels, test_size = 0.2, random_state=42)
train_data, val_data, train_labels, val_labels = train_test_split(train_data, train_labels, test_size = 0.2, random_state=42)

# %% [markdown]
# CONSTRUINDO MODELO

# %%
vgg1 = VGG19(input_shape=(176, 176, 3), include_top=False, weights="imagenet")

# %%
vgg1.summary()

# %%
visualkeras.layered_view(vgg1)

# %%
last_output= vgg1.layers[-1].output

last_output= Flatten()(last_output)

pretrained_model= Model(vgg1.input, last_output)

# %%
x= Dense(units=1024, activation="relu")(last_output)
x=Dropout(0.2)(x)

x= Dense(units=512, activation="relu")(last_output)
x=Dropout(0.2)(x)

x= Dense(units=512, activation="relu")(last_output)
x=Dropout(0.2)(x)

x= Dense(units=256, activation="relu")(last_output)
x=Dropout(0.2)(x)

x= Dense(units=256, activation="relu")(last_output)
x=Dropout(0.2)(x)

x= Dense(units=128, activation="relu")(last_output)
x=Dropout(0.2)(x)

x= Dense(units=128, activation="relu")(last_output)
x=Dropout(0.2)(x)

x= Dense(units=64, activation="relu")(x)
x=Dropout(0.2)(x)

x= Dense(units=32, activation="relu")(x)
x=Dropout(0.2)(x)

x= Dense(units=4, activation="softmax")(x)


vgg_model= Model(pretrained_model.input, x)

vgg_model.summary()

# %%
for layer in vgg_model.layers:
    layer.trainable=False

# %%
visualkeras.layered_view(vgg_model)

# %% [markdown]
# METRICAS

# %%
def f1_score(y_true, y_pred): 
    true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
    possible_positives = K.sum(K.round(K.clip(y_true, 0, 1)))
    predicted_positives = K.sum(K.round(K.clip(y_pred, 0, 1)))
    precision = true_positives / (predicted_positives + K.epsilon())
    recall = true_positives / (possible_positives + K.epsilon())
    f1_val = 2*(precision*recall)/(precision+recall+K.epsilon())
    return f1_val

# %%
METRICS = [
            tf.keras.metrics.BinaryAccuracy(name='acuracia'),
            tf.keras.metrics.Precision(name='precisão'),
            tf.keras.metrics.Recall(name='recall'),  
            tf.keras.metrics.AUC(name='auc'),
            #tfa.metrics.F1Score(num_classes=4)
            f1_score
           ]

# %%
def exponential_decay(lr0, s):
    def exponential_decay_fn(epoch):
        return lr0 * 0.1 **(epoch / s)
    return exponential_decay_fn

exponential_decay_fn = exponential_decay(0.001, 5) 

lr_scheduler = tf.keras.callbacks.LearningRateScheduler(exponential_decay_fn)

# %%
vgg_model.compile(optimizer='rmsprop',
                              loss=tf.losses.CategoricalCrossentropy(),
                              metrics=METRICS)

# %%
#Fit dos dados de treinamento ao modelo e validá-lo usando os dados de validação

history = vgg_model.fit(train_data,
           train_labels,
           validation_data= (val_data, val_labels),
           epochs = 200,
           verbose = 1,
           callbacks=lr_scheduler
          )
# Out:
# Epoch 1/200
# 128/128 [==============================] - 38s 279ms/step - loss: 1.3080 - acuracia: 0.7450 - precisão: 0.3765 - recall: 0.0305 - auc: 0.6563 - f1_score: 0.0553 - val_loss: 1.2300 - val_acuracia: 0.7500 - val_precisão: 0.0000e+00 - val_recall: 0.0000e+00 - val_auc: 0.7485 - val_f1_score: 0.0000e+00 - lr: 0.0010
# Epoch 2/200
# 128/128 [==============================] - 35s 271ms/step - loss: 1.3202 - acuracia: 0.7452 - precisão: 0.3789 - recall: 0.0298 - auc: 0.6452 - f1_score: 0.0542 - val_loss: 1.2300 - val_acuracia: 0.7500 - val_precisão: 0.0000e+00 - val_recall: 0.0000e+00 - val_auc: 0.7485 - val_f1_score: 0.0000e+00 - lr: 6.3096e-04
# Epoch 3/200
# 128/128 [==============================] - 35s 273ms/step - loss: 1.3126 - acuracia: 0.7456 - precisão: 0.3882 - recall: 0.0305 - auc: 0.6528 - f1_score: 0.0553 - val_loss: 1.2300 - val_acuracia: 0.7500 - val_precisão: 0.0000e+00 - val_recall: 0.0000e+00 - val_auc: 0.7485 - val_f1_score: 0.0000e+00 - lr: 3.9811e-04
# Epoch 4/200
# 128/128 [==============================] - 38s 300ms/step - loss: 1.3154 - acuracia: 0.7457 - precisão: 0.3887 - recall: 0.0303 - auc: 0.6486 - f1_score: 0.0550 - val_loss: 1.2300 - val_acuracia: 0.7500 - val_precisão: 0.0000e+00 - val_recall: 0.0000e+00 - val_auc: 0.7485 - val_f1_score: 0.0000e+00 - lr: 2.5119e-04
# Epoch 5/200
# 128/128 [==============================] - 35s 274ms/step - loss: 1.3104 - acuracia: 0.7467 - precisão: 0.4161 - recall: 0.0327 - auc: 0.6537 - f1_score: 0.0595 - val_loss: 1.2300 - val_acuracia: 0.7500 - val_precisão: 0.0000e+00 - val_recall: 0.0000e+00 - val_auc: 0.7485 - val_f1_score: 0.0000e+00 - lr: 1.5849e-04
# Epoch 6/200
# 128/128 [==============================] - 35s 273ms/step - loss: 1.3107 - acuracia: 0.7458 - precisão: 0.4029 - recall: 0.0344 - auc: 0.6541 - f1_score: 0.0618 - val_loss: 1.2300 - val_acuracia: 0.7500 - val_precisão: 0.0000e+00 - val_recall: 0.0000e+00 - val_auc: 0.7485 - val_f1_score: 0.0000e+00 - lr: 1.0000e-04
# Epoch 7/200
# 128/128 [==============================] - 35s 273ms/step - loss: 1.2974 - acuracia: 0.7458 - precisão: 0.3869 - recall: 0.0288 - auc: 0.6650 - f1_score: 0.0524 - val_loss: 1.2300 - val_acuracia: 0.7500 - val_precisão: 0.0000e+00 - val_recall: 0.0000e+00 - val_auc: 0.7485 - val_f1_score: 0.0000e+00 - lr: 6.3096e-05
# Epoch 8/200
# 128/128 [==============================] - 35s 273ms/step - loss: 1.3117 - acuracia: 0.7440 - precisão: 0.3438 - recall: 0.0266 - auc: 0.6533 - f1_score: 0.0485 - val_loss: 1.2300 - val_acuracia: 0.7500 - val_precisão: 0.0000e+00 - val_recall: 0.0000e+00 - val_auc: 0.7485 - val_f1_score: 0.0000e+00 - lr: 3.9811e-05
# Epoch 9/200
# 128/128 [==============================] - 35s 273ms/step - loss: 1.3175 - acuracia: 0.7455 - precisão: 0.3954 - recall: 0.0337 - auc: 0.6490 - f1_score: 0.0606 - val_loss: 1.2300 - val_acuracia: 0.7500 - val_precisão: 0.0000e+00 - val_recall: 0.0000e+00 - val_auc: 0.7485 - val_f1_score: 0.0000e+00 - lr: 2.5119e-05
# Epoch 10/200
# 128/128 [==============================] - 35s 274ms/step - loss: 1.3068 - acuracia: 0.7443 - precisão: 0.3560 - recall: 0.0281 - auc: 0.6571 - f1_score: 0.0508 - val_loss: 1.2300 - val_acuracia: 0.7500 - val_precisão: 0.0000e+00 - val_recall: 0.0000e+00 - val_auc: 0.7485 - val_f1_score: 0.0000e+00 - lr: 1.5849e-05
# Epoch 11/200
# 128/128 [==============================] - 35s 273ms/step - loss: 1.3034 - acuracia: 0.7449 - precisão: 0.3793 - recall: 0.0322 - auc: 0.6596 - f1_score: 0.0581 - val_loss: 1.2300 - val_acuracia: 0.7500 - val_precisão: 0.0000e+00 - val_recall: 0.0000e+00 - val_auc: 0.7485 - val_f1_score: 0.0000e+00 - lr: 1.0000e-05
# Epoch 12/200
# 128/128 [==============================] - 35s 274ms/step - loss: 1.3231 - acuracia: 0.7444 - precisão: 0.3583 - recall: 0.0281 - auc: 0.6438 - f1_score: 0.0504 - val_loss: 1.2300 - val_acuracia: 0.7500 - val_precisão: 0.0000e+00 - val_recall: 0.0000e+00 - val_auc: 0.7485 - val_f1_score: 0.0000e+00 - lr: 6.3096e-06
# Epoch 13/200
# 128/128 [==============================] - 35s 274ms/step - loss: 1.3057 - acuracia: 0.7457 - precisão: 0.4006 - recall: 0.0349 - auc: 0.6584 - f1_score: 0.0626 - val_loss: 1.2300 - val_acuracia: 0.7500 - val_precisão: 0.0000e+00 - val_recall: 0.0000e+00 - val_auc: 0.7485 - val_f1_score: 0.0000e+00 - lr: 3.9811e-06
# Epoch 14/200
# 128/128 [==============================] - 35s 273ms/step - loss: 1.3109 - acuracia: 0.7466 - precisão: 0.4164 - recall: 0.0334 - auc: 0.6542 - f1_score: 0.0607 - val_loss: 1.2300 - val_acuracia: 0.7500 - val_precisão: 0.0000e+00 - val_recall: 0.0000e+00 - val_auc: 0.7485 - val_f1_score: 0.0000e+00 - lr: 2.5119e-06
# Epoch 15/200
# 128/128 [==============================] - 35s 274ms/step - loss: 1.3054 - acuracia: 0.7457 - precisão: 0.3959 - recall: 0.0330 - auc: 0.6583 - f1_score: 0.0592 - val_loss: 1.2300 - val_acuracia: 0.7500 - val_precisão: 0.0000e+00 - val_recall: 0.0000e+00 - val_auc: 0.7485 - val_f1_score: 0.0000e+00 - lr: 1.5849e-06
# Epoch 16/200
# 128/128 [==============================] - 35s 273ms/step - loss: 1.3063 - acuracia: 0.7450 - precisão: 0.3651 - recall: 0.0271 - auc: 0.6587 - f1_score: 0.0491 - val_loss: 1.2300 - val_acuracia: 0.7500 - val_precisão: 0.0000e+00 - val_recall: 0.0000e+00 - val_auc: 0.7485 - val_f1_score: 0.0000e+00 - lr: 1.0000e-06
# Epoch 17/200
# 128/128 [==============================] - 35s 274ms/step - loss: 1.3126 - acuracia: 0.7462 - precisão: 0.4054 - recall: 0.0330 - auc: 0.6547 - f1_score: 0.0595 - val_loss: 1.2300 - val_acuracia: 0.7500 - val_precisão: 0.0000e+00 - val_recall: 0.0000e+00 - val_auc: 0.7485 - val_f1_score: 0.0000e+00 - lr: 6.3096e-07
# Epoch 18/200
# 128/128 [==============================] - 35s 274ms/step - loss: 1.2987 - acuracia: 0.7445 - precisão: 0.3620 - recall: 0.0288 - auc: 0.6642 - f1_score: 0.0523 - val_loss: 1.2300 - val_acuracia: 0.7500 - val_precisão: 0.0000e+00 - val_recall: 0.0000e+00 - val_auc: 0.7485 - val_f1_score: 0.0000e+00 - lr: 3.9811e-07
# Epoch 19/200
# 128/128 [==============================] - 35s 273ms/step - loss: 1.3023 - acuracia: 0.7470 - precisão: 0.4298 - recall: 0.0366 - auc: 0.6592 - f1_score: 0.0658 - val_loss: 1.2300 - val_acuracia: 0.7500 - val_precisão: 0.0000e+00 - val_recall: 0.0000e+00 - val_auc: 0.7485 - val_f1_score: 0.0000e+00 - lr: 2.5119e-07
# Epoch 20/200
# 128/128 [==============================] - 35s 273ms/step - loss: 1.3179 - acuracia: 0.7444 - precisão: 0.3562 - recall: 0.0278 - auc: 0.6495 - f1_score: 0.0505 - val_loss: 1.2300 - val_acuracia: 0.7500 - val_precisão: 0.0000e+00 - val_recall: 0.0000e+00 - val_auc: 0.7485 - val_f1_score: 0.0000e+00 - lr: 1.5849e-07
# Epoch 21/200
# 128/128 [==============================] - 35s 273ms/step - loss: 1.3064 - acuracia: 0.7453 - precisão: 0.3801 - recall: 0.0298 - auc: 0.6559 - f1_score: 0.0540 - val_loss: 1.2300 - val_acuracia: 0.7500 - val_precisão: 0.0000e+00 - val_recall: 0.0000e+00 - val_auc: 0.7485 - val_f1_score: 0.0000e+00 - lr: 1.0000e-07
# Epoch 22/200
# 128/128 [==============================] - 35s 273ms/step - loss: 1.3143 - acuracia: 0.7439 - precisão: 0.3387 - recall: 0.0256 - auc: 0.6515 - f1_score: 0.0467 - val_loss: 1.2300 - val_acuracia: 0.7500 - val_precisão: 0.0000e+00 - val_recall: 0.0000e+00 - val_auc: 0.7485 - val_f1_score: 0.0000e+00 - lr: 6.3096e-08
# Epoch 23/200
# 128/128 [==============================] - 35s 273ms/step - loss: 1.3177 - acuracia: 0.7451 - precisão: 0.3812 - recall: 0.0317 - auc: 0.6465 - f1_score: 0.0572 - val_loss: 1.2300 - val_acuracia: 0.7500 - val_precisão: 0.0000e+00 - val_recall: 0.0000e+00 - val_auc: 0.7485 - val_f1_score: 0.0000e+00 - lr: 3.9811e-08
# Epoch 24/200
# 128/128 [==============================] - 35s 273ms/step - loss: 1.3104 - acuracia: 0.7445 - precisão: 0.3576 - recall: 0.0276 - auc: 0.6520 - f1_score: 0.0502 - val_loss: 1.2300 - val_acuracia: 0.7500 - val_precisão: 0.0000e+00 - val_recall: 0.0000e+00 - val_auc: 0.7485 - val_f1_score: 0.0000e+00 - lr: 2.5119e-08
# Epoch 25/200
# 128/128 [==============================] - 35s 273ms/step - loss: 1.3190 - acuracia: 0.7448 - precisão: 0.3689 - recall: 0.0295 - auc: 0.6466 - f1_score: 0.0534 - val_loss: 1.2300 - val_acuracia: 0.7500 - val_precisão: 0.0000e+00 - val_recall: 0.0000e+00 - val_auc: 0.7485 - val_f1_score: 0.0000e+00 - lr: 1.5849e-08
# Epoch 26/200
# 128/128 [==============================] - 35s 273ms/step - loss: 1.3094 - acuracia: 0.7451 - precisão: 0.3684 - recall: 0.0273 - auc: 0.6551 - f1_score: 0.0496 - val_loss: 1.2300 - val_acuracia: 0.7500 - val_precisão: 0.0000e+00 - val_recall: 0.0000e+00 - val_auc: 0.7485 - val_f1_score: 0.0000e+00 - lr: 1.0000e-08
# Epoch 27/200
# 128/128 [==============================] - 35s 273ms/step - loss: 1.3026 - acuracia: 0.7454 - precisão: 0.3855 - recall: 0.0312 - auc: 0.6609 - f1_score: 0.0561 - val_loss: 1.2300 - val_acuracia: 0.7500 - val_precisão: 0.0000e+00 - val_recall: 0.0000e+00 - val_auc: 0.7485 - val_f1_score: 0.0000e+00 - lr: 6.3096e-09
# Epoch 28/200
# 128/128 [==============================] - 35s 273ms/step - loss: 1.3170 - acuracia: 0.7426 - precisão: 0.3195 - recall: 0.0264 - auc: 0.6485 - f1_score: 0.0475 - val_loss: 1.2300 - val_acuracia: 0.7500 - val_precisão: 0.0000e+00 - val_recall: 0.0000e+00 - val_auc: 0.7485 - val_f1_score: 0.0000e+00 - lr: 3.9811e-09
# Epoch 29/200
# 128/128 [==============================] - 35s 273ms/step - loss: 1.3064 - acuracia: 0.7466 - precisão: 0.4159 - recall: 0.0332 - auc: 0.6574 - f1_score: 0.0600 - val_loss: 1.2300 - val_acuracia: 0.7500 - val_precisão: 0.0000e+00 - val_recall: 0.0000e+00 - val_auc: 0.7485 - val_f1_score: 0.0000e+00 - lr: 2.5119e-09
# Epoch 30/200
# 128/128 [==============================] - 35s 273ms/step - loss: 1.3045 - acuracia: 0.7456 - precisão: 0.4062 - recall: 0.0381 - auc: 0.6595 - f1_score: 0.0680 - val_loss: 1.2300 - val_acuracia: 0.7500 - val_precisão: 0.0000e+00 - val_recall: 0.0000e+00 - val_auc: 0.7485 - val_f1_score: 0.0000e+00 - lr: 1.5849e-09
# Epoch 31/200
# 128/128 [==============================] - 35s 274ms/step - loss: 1.3085 - acuracia: 0.7461 - precisão: 0.4091 - recall: 0.0352 - auc: 0.6563 - f1_score: 0.0634 - val_loss: 1.2300 - val_acuracia: 0.7500 - val_precisão: 0.0000e+00 - val_recall: 0.0000e+00 - val_auc: 0.7485 - val_f1_score: 0.0000e+00 - lr: 1.0000e-09
# Epoch 32/200
# 128/128 [==============================] - 35s 273ms/step - loss: 1.3085 - acuracia: 0.7449 - precisão: 0.3739 - recall: 0.0300 - auc: 0.6561 - f1_score: 0.0540 - val_loss: 1.2300 - val_acuracia: 0.7500 - val_precisão: 0.0000e+00 - val_recall: 0.0000e+00 - val_auc: 0.7485 - val_f1_score: 0.0000e+00 - lr: 6.3096e-10
# Epoch 33/200
# 128/128 [==============================] - 35s 273ms/step - loss: 1.3099 - acuracia: 0.7455 - precisão: 0.3949 - recall: 0.0339 - auc: 0.6542 - f1_score: 0.0612 - val_loss: 1.2300 - val_acuracia: 0.7500 - val_precisão: 0.0000e+00 - val_recall: 0.0000e+00 - val_auc: 0.7485 - val_f1_score: 0.0000e+00 - lr: 3.9811e-10
# Epoch 34/200
# 128/128 [==============================] - 35s 273ms/step - loss: 1.3128 - acuracia: 0.7455 - precisão: 0.3844 - recall: 0.0300 - auc: 0.6514 - f1_score: 0.0545 - val_loss: 1.2300 - val_acuracia: 0.7500 - val_precisão: 0.0000e+00 - val_recall: 0.0000e+00 - val_auc: 0.7485 - val_f1_score: 0.0000e+00 - lr: 2.5119e-10
# Epoch 35/200
# 128/128 [==============================] - 35s 273ms/step - loss: 1.3103 - acuracia: 0.7457 - precisão: 0.3983 - recall: 0.0339 - auc: 0.6534 - f1_score: 0.0610 - val_loss: 1.2300 - val_acuracia: 0.7500 - val_precisão: 0.0000e+00 - val_recall: 0.0000e+00 - val_auc: 0.7485 - val_f1_score: 0.0000e+00 - lr: 1.5849e-10
# Epoch 36/200
# 128/128 [==============================] - 35s 273ms/step - loss: 1.3124 - acuracia: 0.7457 - precisão: 0.3833 - recall: 0.0281 - auc: 0.6505 - f1_score: 0.0513 - val_loss: 1.2300 - val_acuracia: 0.7500 - val_precisão: 0.0000e+00 - val_recall: 0.0000e+00 - val_auc: 0.7485 - val_f1_score: 0.0000e+00 - lr: 1.0000e-10
# Epoch 37/200
# 128/128 [==============================] - 35s 273ms/step - loss: 1.3178 - acuracia: 0.7433 - precisão: 0.3402 - recall: 0.0283 - auc: 0.6486 - f1_score: 0.0510 - val_loss: 1.2300 - val_acuracia: 0.7500 - val_precisão: 0.0000e+00 - val_recall: 0.0000e+00 - val_auc: 0.7485 - val_f1_score: 0.0000e+00 - lr: 6.3096e-11
# Epoch 38/200
# 128/128 [==============================] - 35s 273ms/step - loss: 1.3107 - acuracia: 0.7444 - precisão: 0.3678 - recall: 0.0312 - auc: 0.6559 - f1_score: 0.0562 - val_loss: 1.2300 - val_acuracia: 0.7500 - val_precisão: 0.0000e+00 - val_recall: 0.0000e+00 - val_auc: 0.7485 - val_f1_score: 0.0000e+00 - lr: 3.9811e-11
# Epoch 39/200
# 128/128 [==============================] - 35s 273ms/step - loss: 1.3162 - acuracia: 0.7431 - precisão: 0.3313 - recall: 0.0271 - auc: 0.6494 - f1_score: 0.0490 - val_loss: 1.2300 - val_acuracia: 0.7500 - val_precisão: 0.0000e+00 - val_recall: 0.0000e+00 - val_auc: 0.7485 - val_f1_score: 0.0000e+00 - lr: 2.5119e-11
# Epoch 40/200
# 128/128 [==============================] - 35s 273ms/step - loss: 1.3159 - acuracia: 0.7440 - precisão: 0.3582 - recall: 0.0305 - auc: 0.6499 - f1_score: 0.0549 - val_loss: 1.2300 - val_acuracia: 0.7500 - val_precisão: 0.0000e+00 - val_recall: 0.0000e+00 - val_auc: 0.7485 - val_f1_score: 0.0000e+00 - lr: 1.5849e-11
# Epoch 41/200
# 128/128 [==============================] - 35s 273ms/step - loss: 1.3098 - acuracia: 0.7449 - precisão: 0.3827 - recall: 0.0334 - auc: 0.6563 - f1_score: 0.0600 - val_loss: 1.2300 - val_acuracia: 0.7500 - val_precisão: 0.0000e+00 - val_recall: 0.0000e+00 - val_auc: 0.7485 - val_f1_score: 0.0000e+00 - lr: 1.0000e-11
# Epoch 42/200
# 128/128 [==============================] - 35s 273ms/step - loss: 1.3147 - acuracia: 0.7452 - precisão: 0.3821 - recall: 0.0312 - auc: 0.6506 - f1_score: 0.0560 - val_loss: 1.2300 - val_acuracia: 0.7500 - val_precisão: 0.0000e+00 - val_recall: 0.0000e+00 - val_auc: 0.7485 - val_f1_score: 0.0000e+00 - lr: 6.3096e-12
# Epoch 43/200
# 128/128 [==============================] - 35s 273ms/step - loss: 1.3179 - acuracia: 0.7457 - precisão: 0.3859 - recall: 0.0293 - auc: 0.6492 - f1_score: 0.0533 - val_loss: 1.2300 - val_acuracia: 0.7500 - val_precisão: 0.0000e+00 - val_recall: 0.0000e+00 - val_auc: 0.7485 - val_f1_score: 0.0000e+00 - lr: 3.9811e-12
# Epoch 44/200
# 128/128 [==============================] - 35s 273ms/step - loss: 1.3101 - acuracia: 0.7439 - precisão: 0.3466 - recall: 0.0276 - auc: 0.6544 - f1_score: 0.0499 - val_loss: 1.2300 - val_acuracia: 0.7500 - val_precisão: 0.0000e+00 - val_recall: 0.0000e+00 - val_auc: 0.7485 - val_f1_score: 0.0000e+00 - lr: 2.5119e-12
# Epoch 45/200
# 128/128 [==============================] - 35s 273ms/step - loss: 1.3174 - acuracia: 0.7455 - precisão: 0.3972 - recall: 0.0349 - auc: 0.6476 - f1_score: 0.0625 - val_loss: 1.2300 - val_acuracia: 0.7500 - val_precisão: 0.0000e+00 - val_recall: 0.0000e+00 - val_auc: 0.7485 - val_f1_score: 0.0000e+00 - lr: 1.5849e-12
# Epoch 46/200
# 128/128 [==============================] - 35s 274ms/step - loss: 1.3128 - acuracia: 0.7456 - precisão: 0.3861 - recall: 0.0298 - auc: 0.6517 - f1_score: 0.0536 - val_loss: 1.2300 - val_acuracia: 0.7500 - val_precisão: 0.0000e+00 - val_recall: 0.0000e+00 - val_auc: 0.7485 - val_f1_score: 0.0000e+00 - lr: 1.0000e-12
# Epoch 47/200
# 128/128 [==============================] - 35s 273ms/step - loss: 1.3093 - acuracia: 0.7460 - precisão: 0.4063 - recall: 0.0344 - auc: 0.6544 - f1_score: 0.0621 - val_loss: 1.2300 - val_acuracia: 0.7500 - val_precisão: 0.0000e+00 - val_recall: 0.0000e+00 - val_auc: 0.7485 - val_f1_score: 0.0000e+00 - lr: 6.3096e-13
# Epoch 48/200
# 128/128 [==============================] - 35s 273ms/step - loss: 1.3161 - acuracia: 0.7440 - precisão: 0.3429 - recall: 0.0264 - auc: 0.6501 - f1_score: 0.0475 - val_loss: 1.2300 - val_acuracia: 0.7500 - val_precisão: 0.0000e+00 - val_recall: 0.0000e+00 - val_auc: 0.7485 - val_f1_score: 0.0000e+00 - lr: 3.9811e-13
# Epoch 49/200
# 128/128 [==============================] - 35s 273ms/step - loss: 1.3019 - acuracia: 0.7466 - precisão: 0.4152 - recall: 0.0334 - auc: 0.6601 - f1_score: 0.0605 - val_loss: 1.2300 - val_acuracia: 0.7500 - val_precisão: 0.0000e+00 - val_recall: 0.0000e+00 - val_auc: 0.7485 - val_f1_score: 0.0000e+00 - lr: 2.5119e-13
# Epoch 50/200
# 128/128 [==============================] - 35s 275ms/step - loss: 1.3045 - acuracia: 0.7462 - precisão: 0.3994 - recall: 0.0305 - auc: 0.6586 - f1_score: 0.0553 - val_loss: 1.2300 - val_acuracia: 0.7500 - val_precisão: 0.0000e+00 - val_recall: 0.0000e+00 - val_auc: 0.7485 - val_f1_score: 0.0000e+00 - lr: 1.5849e-13
# Epoch 51/200
# 128/128 [==============================] - 35s 275ms/step - loss: 1.3178 - acuracia: 0.7447 - precisão: 0.3636 - recall: 0.0283 - auc: 0.6483 - f1_score: 0.0512 - val_loss: 1.2300 - val_acuracia: 0.7500 - val_precisão: 0.0000e+00 - val_recall: 0.0000e+00 - val_auc: 0.7485 - val_f1_score: 0.0000e+00 - lr: 1.0000e-13
# Epoch 52/200
# 128/128 [==============================] - 35s 274ms/step - loss: 1.3130 - acuracia: 0.7451 - precisão: 0.3706 - recall: 0.0283 - auc: 0.6521 - f1_score: 0.0512 - val_loss: 1.2300 - val_acuracia: 0.7500 - val_precisão: 0.0000e+00 - val_recall: 0.0000e+00 - val_auc: 0.7485 - val_f1_score: 0.0000e+00 - lr: 6.3096e-14
# Epoch 53/200
# 128/128 [==============================] - 35s 275ms/step - loss: 1.3126 - acuracia: 0.7446 - precisão: 0.3659 - recall: 0.0293 - auc: 0.6523 - f1_score: 0.0528 - val_loss: 1.2300 - val_acuracia: 0.7500 - val_precisão: 0.0000e+00 - val_recall: 0.0000e+00 - val_auc: 0.7485 - val_f1_score: 0.0000e+00 - lr: 3.9811e-14
# Epoch 54/200
# 128/128 [==============================] - 35s 275ms/step - loss: 1.3083 - acuracia: 0.7466 - precisão: 0.4127 - recall: 0.0317 - auc: 0.6574 - f1_score: 0.0575 - val_loss: 1.2300 - val_acuracia: 0.7500 - val_precisão: 0.0000e+00 - val_recall: 0.0000e+00 - val_auc: 0.7485 - val_f1_score: 0.0000e+00 - lr: 2.5119e-14
# Epoch 55/200
# 128/128 [==============================] - 35s 275ms/step - loss: 1.3063 - acuracia: 0.7465 - precisão: 0.4142 - recall: 0.0342 - auc: 0.6588 - f1_score: 0.0613 - val_loss: 1.2300 - val_acuracia: 0.7500 - val_precisão: 0.0000e+00 - val_recall: 0.0000e+00 - val_auc: 0.7485 - val_f1_score: 0.0000e+00 - lr: 1.5849e-14
# Epoch 56/200
# 128/128 [==============================] - 35s 274ms/step - loss: 1.3116 - acuracia: 0.7451 - precisão: 0.3754 - recall: 0.0298 - auc: 0.6522 - f1_score: 0.0539 - val_loss: 1.2300 - val_acuracia: 0.7500 - val_precisão: 0.0000e+00 - val_recall: 0.0000e+00 - val_auc: 0.7485 - val_f1_score: 0.0000e+00 - lr: 1.0000e-14
# Epoch 57/200
# 128/128 [==============================] - 35s 274ms/step - loss: 1.3083 - acuracia: 0.7459 - precisão: 0.3976 - recall: 0.0317 - auc: 0.6573 - f1_score: 0.0576 - val_loss: 1.2300 - val_acuracia: 0.7500 - val_precisão: 0.0000e+00 - val_recall: 0.0000e+00 - val_auc: 0.7485 - val_f1_score: 0.0000e+00 - lr: 6.3096e-15
# Epoch 58/200
# 128/128 [==============================] - 35s 275ms/step - loss: 1.3047 - acuracia: 0.7432 - precisão: 0.3333 - recall: 0.0271 - auc: 0.6592 - f1_score: 0.0486 - val_loss: 1.2300 - val_acuracia: 0.7500 - val_precisão: 0.0000e+00 - val_recall: 0.0000e+00 - val_auc: 0.7485 - val_f1_score: 0.0000e+00 - lr: 3.9811e-15
# Epoch 59/200
# 128/128 [==============================] - 35s 275ms/step - loss: 1.3070 - acuracia: 0.7469 - precisão: 0.4180 - recall: 0.0317 - auc: 0.6575 - f1_score: 0.0578 - val_loss: 1.2300 - val_acuracia: 0.7500 - val_precisão: 0.0000e+00 - val_recall: 0.0000e+00 - val_auc: 0.7485 - val_f1_score: 0.0000e+00 - lr: 2.5119e-15
# Epoch 60/200
# 128/128 [==============================] - 35s 275ms/step - loss: 1.3062 - acuracia: 0.7458 - precisão: 0.3964 - recall: 0.0322 - auc: 0.6584 - f1_score: 0.0584 - val_loss: 1.2300 - val_acuracia: 0.7500 - val_precisão: 0.0000e+00 - val_recall: 0.0000e+00 - val_auc: 0.7485 - val_f1_score: 0.0000e+00 - lr: 1.5849e-15
# Epoch 61/200
# 128/128 [==============================] - 35s 275ms/step - loss: 1.3086 - acuracia: 0.7454 - precisão: 0.3876 - recall: 0.0320 - auc: 0.6577 - f1_score: 0.0579 - val_loss: 1.2300 - val_acuracia: 0.7500 - val_precisão: 0.0000e+00 - val_recall: 0.0000e+00 - val_auc: 0.7485 - val_f1_score: 0.0000e+00 - lr: 1.0000e-15
# Epoch 62/200
# 128/128 [==============================] - 35s 275ms/step - loss: 1.3109 - acuracia: 0.7440 - precisão: 0.3540 - recall: 0.0293 - auc: 0.6557 - f1_score: 0.0527 - val_loss: 1.2300 - val_acuracia: 0.7500 - val_precisão: 0.0000e+00 - val_recall: 0.0000e+00 - val_auc: 0.7485 - val_f1_score: 0.0000e+00 - lr: 6.3096e-16
# Epoch 63/200
# 128/128 [==============================] - 35s 275ms/step - loss: 1.2995 - acuracia: 0.7457 - precisão: 0.3988 - recall: 0.0337 - auc: 0.6644 - f1_score: 0.0608 - val_loss: 1.2300 - val_acuracia: 0.7500 - val_precisão: 0.0000e+00 - val_recall: 0.0000e+00 - val_auc: 0.7485 - val_f1_score: 0.0000e+00 - lr: 3.9811e-16
# Epoch 64/200
# 128/128 [==============================] - 35s 275ms/step - loss: 1.3074 - acuracia: 0.7468 - precisão: 0.4167 - recall: 0.0317 - auc: 0.6575 - f1_score: 0.0576 - val_loss: 1.2300 - val_acuracia: 0.7500 - val_precisão: 0.0000e+00 - val_recall: 0.0000e+00 - val_auc: 0.7485 - val_f1_score: 0.0000e+00 - lr: 2.5119e-16
# Epoch 65/200
# 128/128 [==============================] - 35s 275ms/step - loss: 1.3016 - acuracia: 0.7463 - precisão: 0.4126 - recall: 0.0352 - auc: 0.6611 - f1_score: 0.0633 - val_loss: 1.2300 - val_acuracia: 0.7500 - val_precisão: 0.0000e+00 - val_recall: 0.0000e+00 - val_auc: 0.7485 - val_f1_score: 0.0000e+00 - lr: 1.5849e-16
# Epoch 66/200
# 128/128 [==============================] - 35s 275ms/step - loss: 1.3121 - acuracia: 0.7442 - precisão: 0.3591 - recall: 0.0295 - auc: 0.6539 - f1_score: 0.0531 - val_loss: 1.2300 - val_acuracia: 0.7500 - val_precisão: 0.0000e+00 - val_recall: 0.0000e+00 - val_auc: 0.7485 - val_f1_score: 0.0000e+00 - lr: 1.0000e-16
# Epoch 67/200
# 128/128 [==============================] - 35s 275ms/step - loss: 1.3184 - acuracia: 0.7444 - precisão: 0.3583 - recall: 0.0281 - auc: 0.6484 - f1_score: 0.0509 - val_loss: 1.2300 - val_acuracia: 0.7500 - val_precisão: 0.0000e+00 - val_recall: 0.0000e+00 - val_auc: 0.7485 - val_f1_score: 0.0000e+00 - lr: 6.3096e-17
# Epoch 68/200
# 128/128 [==============================] - 35s 275ms/step - loss: 1.3066 - acuracia: 0.7448 - precisão: 0.3761 - recall: 0.0315 - auc: 0.6579 - f1_score: 0.0570 - val_loss: 1.2300 - val_acuracia: 0.7500 - val_precisão: 0.0000e+00 - val_recall: 0.0000e+00 - val_auc: 0.7485 - val_f1_score: 0.0000e+00 - lr: 3.9811e-17
# Epoch 69/200
# 128/128 [==============================] - 35s 275ms/step - loss: 1.3035 - acuracia: 0.7446 - precisão: 0.3647 - recall: 0.0293 - auc: 0.6603 - f1_score: 0.0527 - val_loss: 1.2300 - val_acuracia: 0.7500 - val_precisão: 0.0000e+00 - val_recall: 0.0000e+00 - val_auc: 0.7485 - val_f1_score: 0.0000e+00 - lr: 2.5119e-17
# Epoch 70/200
# 128/128 [==============================] - 35s 275ms/step - loss: 1.3012 - acuracia: 0.7465 - precisão: 0.4071 - recall: 0.0310 - auc: 0.6603 - f1_score: 0.0563 - val_loss: 1.2300 - val_acuracia: 0.7500 - val_precisão: 0.0000e+00 - val_recall: 0.0000e+00 - val_auc: 0.7485 - val_f1_score: 0.0000e+00 - lr: 1.5849e-17
# Epoch 71/200
# 128/128 [==============================] - 35s 274ms/step - loss: 1.3174 - acuracia: 0.7443 - precisão: 0.3660 - recall: 0.0310 - auc: 0.6479 - f1_score: 0.0561 - val_loss: 1.2300 - val_acuracia: 0.7500 - val_precisão: 0.0000e+00 - val_recall: 0.0000e+00 - val_auc: 0.7485 - val_f1_score: 0.0000e+00 - lr: 1.0000e-17
# Epoch 72/200
# 128/128 [==============================] - 35s 274ms/step - loss: 1.3056 - acuracia: 0.7452 - precisão: 0.3848 - recall: 0.0322 - auc: 0.6575 - f1_score: 0.0585 - val_loss: 1.2300 - val_acuracia: 0.7500 - val_precisão: 0.0000e+00 - val_recall: 0.0000e+00 - val_auc: 0.7485 - val_f1_score: 0.0000e+00 - lr: 6.3096e-18
# Epoch 73/200
# 128/128 [==============================] - 35s 275ms/step - loss: 1.3160 - acuracia: 0.7432 - precisão: 0.3401 - recall: 0.0288 - auc: 0.6543 - f1_score: 0.0518 - val_loss: 1.2300 - val_acuracia: 0.7500 - val_precisão: 0.0000e+00 - val_recall: 0.0000e+00 - val_auc: 0.7485 - val_f1_score: 0.0000e+00 - lr: 3.9811e-18
# Epoch 74/200
# 128/128 [==============================] - 35s 275ms/step - loss: 1.3021 - acuracia: 0.7431 - precisão: 0.3343 - recall: 0.0278 - auc: 0.6590 - f1_score: 0.0497 - val_loss: 1.2300 - val_acuracia: 0.7500 - val_precisão: 0.0000e+00 - val_recall: 0.0000e+00 - val_auc: 0.7485 - val_f1_score: 0.0000e+00 - lr: 2.5119e-18
# Epoch 75/200
# 128/128 [==============================] - 35s 275ms/step - loss: 1.3177 - acuracia: 0.7446 - precisão: 0.3713 - recall: 0.0310 - auc: 0.6494 - f1_score: 0.0559 - val_loss: 1.2300 - val_acuracia: 0.7500 - val_precisão: 0.0000e+00 - val_recall: 0.0000e+00 - val_auc: 0.7485 - val_f1_score: 0.0000e+00 - lr: 1.5849e-18
# Epoch 76/200
# 128/128 [==============================] - 35s 276ms/step - loss: 1.3113 - acuracia: 0.7448 - precisão: 0.3705 - recall: 0.0300 - auc: 0.6537 - f1_score: 0.0545 - val_loss: 1.2300 - val_acuracia: 0.7500 - val_precisão: 0.0000e+00 - val_recall: 0.0000e+00 - val_auc: 0.7485 - val_f1_score: 0.0000e+00 - lr: 1.0000e-18
# Epoch 77/200
# 128/128 [==============================] - 35s 275ms/step - loss: 1.3066 - acuracia: 0.7455 - precisão: 0.3936 - recall: 0.0330 - auc: 0.6570 - f1_score: 0.0589 - val_loss: 1.2300 - val_acuracia: 0.7500 - val_precisão: 0.0000e+00 - val_recall: 0.0000e+00 - val_auc: 0.7485 - val_f1_score: 0.0000e+00 - lr: 6.3096e-19
# Epoch 78/200
# 128/128 [==============================] - 35s 275ms/step - loss: 1.3119 - acuracia: 0.7463 - precisão: 0.4074 - recall: 0.0322 - auc: 0.6536 - f1_score: 0.0582 - val_loss: 1.2300 - val_acuracia: 0.7500 - val_precisão: 0.0000e+00 - val_recall: 0.0000e+00 - val_auc: 0.7485 - val_f1_score: 0.0000e+00 - lr: 3.9811e-19
# Epoch 79/200
# 128/128 [==============================] - 35s 275ms/step - loss: 1.3242 - acuracia: 0.7429 - precisão: 0.3294 - recall: 0.0273 - auc: 0.6435 - f1_score: 0.0489 - val_loss: 1.2300 - val_acuracia: 0.7500 - val_precisão: 0.0000e+00 - val_recall: 0.0000e+00 - val_auc: 0.7485 - val_f1_score: 0.0000e+00 - lr: 2.5119e-19
# Epoch 80/200
# 128/128 [==============================] - 35s 275ms/step - loss: 1.3164 - acuracia: 0.7440 - precisão: 0.3419 - recall: 0.0261 - auc: 0.6521 - f1_score: 0.0473 - val_loss: 1.2300 - val_acuracia: 0.7500 - val_precisão: 0.0000e+00 - val_recall: 0.0000e+00 - val_auc: 0.7485 - val_f1_score: 0.0000e+00 - lr: 1.5849e-19
# Epoch 81/200
# 128/128 [==============================] - 35s 274ms/step - loss: 1.3165 - acuracia: 0.7455 - precisão: 0.3924 - recall: 0.0330 - auc: 0.6492 - f1_score: 0.0595 - val_loss: 1.2300 - val_acuracia: 0.7500 - val_precisão: 0.0000e+00 - val_recall: 0.0000e+00 - val_auc: 0.7485 - val_f1_score: 0.0000e+00 - lr: 1.0000e-19
# Epoch 82/200
# 128/128 [==============================] - 35s 274ms/step - loss: 1.3064 - acuracia: 0.7445 - precisão: 0.3558 - recall: 0.0271 - auc: 0.6589 - f1_score: 0.0491 - val_loss: 1.2300 - val_acuracia: 0.7500 - val_precisão: 0.0000e+00 - val_recall: 0.0000e+00 - val_auc: 0.7485 - val_f1_score: 0.0000e+00 - lr: 6.3096e-20
# Epoch 83/200
# 128/128 [==============================] - 35s 274ms/step - loss: 1.3061 - acuracia: 0.7438 - precisão: 0.3446 - recall: 0.0273 - auc: 0.6580 - f1_score: 0.0491 - val_loss: 1.2300 - val_acuracia: 0.7500 - val_precisão: 0.0000e+00 - val_recall: 0.0000e+00 - val_auc: 0.7485 - val_f1_score: 0.0000e+00 - lr: 3.9811e-20
# Epoch 84/200
# 128/128 [==============================] - 35s 274ms/step - loss: 1.3138 - acuracia: 0.7440 - precisão: 0.3458 - recall: 0.0271 - auc: 0.6518 - f1_score: 0.0490 - val_loss: 1.2300 - val_acuracia: 0.7500 - val_precisão: 0.0000e+00 - val_recall: 0.0000e+00 - val_auc: 0.7485 - val_f1_score: 0.0000e+00 - lr: 2.5119e-20
# Epoch 85/200
# 128/128 [==============================] - 35s 274ms/step - loss: 1.3087 - acuracia: 0.7455 - precisão: 0.3955 - recall: 0.0342 - auc: 0.6554 - f1_score: 0.0616 - val_loss: 1.2300 - val_acuracia: 0.7500 - val_precisão: 0.0000e+00 - val_recall: 0.0000e+00 - val_auc: 0.7485 - val_f1_score: 0.0000e+00 - lr: 1.5849e-20
# Epoch 86/200
# 128/128 [==============================] - 35s 275ms/step - loss: 1.3092 - acuracia: 0.7452 - precisão: 0.3792 - recall: 0.0303 - auc: 0.6555 - f1_score: 0.0545 - val_loss: 1.2300 - val_acuracia: 0.7500 - val_precisão: 0.0000e+00 - val_recall: 0.0000e+00 - val_auc: 0.7485 - val_f1_score: 0.0000e+00 - lr: 1.0000e-20
# Epoch 87/200
# 128/128 [==============================] - 35s 275ms/step - loss: 1.3122 - acuracia: 0.7457 - precisão: 0.3959 - recall: 0.0330 - auc: 0.6518 - f1_score: 0.0593 - val_loss: 1.2300 - val_acuracia: 0.7500 - val_precisão: 0.0000e+00 - val_recall: 0.0000e+00 - val_auc: 0.7485 - val_f1_score: 0.0000e+00 - lr: 6.3096e-21
# Epoch 88/200
# 128/128 [==============================] - 35s 275ms/step - loss: 1.3084 - acuracia: 0.7437 - precisão: 0.3557 - recall: 0.0310 - auc: 0.6559 - f1_score: 0.0553 - val_loss: 1.2300 - val_acuracia: 0.7500 - val_precisão: 0.0000e+00 - val_recall: 0.0000e+00 - val_auc: 0.7485 - val_f1_score: 0.0000e+00 - lr: 3.9811e-21
# Epoch 89/200
# 128/128 [==============================] - 35s 275ms/step - loss: 1.3159 - acuracia: 0.7447 - precisão: 0.3768 - recall: 0.0325 - auc: 0.6491 - f1_score: 0.0583 - val_loss: 1.2300 - val_acuracia: 0.7500 - val_precisão: 0.0000e+00 - val_recall: 0.0000e+00 - val_auc: 0.7485 - val_f1_score: 0.0000e+00 - lr: 2.5119e-21
# Epoch 90/200
# 128/128 [==============================] - 35s 275ms/step - loss: 1.3102 - acuracia: 0.7451 - precisão: 0.3722 - recall: 0.0288 - auc: 0.6533 - f1_score: 0.0521 - val_loss: 1.2300 - val_acuracia: 0.7500 - val_precisão: 0.0000e+00 - val_recall: 0.0000e+00 - val_auc: 0.7485 - val_f1_score: 0.0000e+00 - lr: 1.5849e-21
# Epoch 91/200
# 128/128 [==============================] - 35s 275ms/step - loss: 1.3128 - acuracia: 0.7457 - precisão: 0.3983 - recall: 0.0334 - auc: 0.6519 - f1_score: 0.0604 - val_loss: 1.2300 - val_acuracia: 0.7500 - val_precisão: 0.0000e+00 - val_recall: 0.0000e+00 - val_auc: 0.7485 - val_f1_score: 0.0000e+00 - lr: 1.0000e-21
# Epoch 92/200
# 128/128 [==============================] - 35s 275ms/step - loss: 1.3194 - acuracia: 0.7437 - precisão: 0.3435 - recall: 0.0276 - auc: 0.6486 - f1_score: 0.0499 - val_loss: 1.2300 - val_acuracia: 0.7500 - val_precisão: 0.0000e+00 - val_recall: 0.0000e+00 - val_auc: 0.7485 - val_f1_score: 0.0000e+00 - lr: 6.3096e-22
# Epoch 93/200
# 128/128 [==============================] - 35s 274ms/step - loss: 1.3137 - acuracia: 0.7440 - precisão: 0.3467 - recall: 0.0273 - auc: 0.6516 - f1_score: 0.0498 - val_loss: 1.2300 - val_acuracia: 0.7500 - val_precisão: 0.0000e+00 - val_recall: 0.0000e+00 - val_auc: 0.7485 - val_f1_score: 0.0000e+00 - lr: 3.9811e-22
# Epoch 94/200
# 128/128 [==============================] - 35s 274ms/step - loss: 1.3147 - acuracia: 0.7443 - precisão: 0.3628 - recall: 0.0300 - auc: 0.6519 - f1_score: 0.0538 - val_loss: 1.2300 - val_acuracia: 0.7500 - val_precisão: 0.0000e+00 - val_recall: 0.0000e+00 - val_auc: 0.7485 - val_f1_score: 0.0000e+00 - lr: 2.5119e-22
# Epoch 95/200
# 128/128 [==============================] - 35s 275ms/step - loss: 1.3144 - acuracia: 0.7443 - precisão: 0.3668 - recall: 0.0312 - auc: 0.6522 - f1_score: 0.0560 - val_loss: 1.2300 - val_acuracia: 0.7500 - val_precisão: 0.0000e+00 - val_recall: 0.0000e+00 - val_auc: 0.7485 - val_f1_score: 0.0000e+00 - lr: 1.5849e-22
# Epoch 96/200
# 128/128 [==============================] - 35s 275ms/step - loss: 1.3154 - acuracia: 0.7457 - precisão: 0.3927 - recall: 0.0317 - auc: 0.6510 - f1_score: 0.0571 - val_loss: 1.2300 - val_acuracia: 0.7500 - val_precisão: 0.0000e+00 - val_recall: 0.0000e+00 - val_auc: 0.7485 - val_f1_score: 0.0000e+00 - lr: 1.0000e-22
# Epoch 97/200
# 128/128 [==============================] - 35s 275ms/step - loss: 1.3069 - acuracia: 0.7451 - precisão: 0.3722 - recall: 0.0288 - auc: 0.6562 - f1_score: 0.0522 - val_loss: 1.2300 - val_acuracia: 0.7500 - val_precisão: 0.0000e+00 - val_recall: 0.0000e+00 - val_auc: 0.7485 - val_f1_score: 0.0000e+00 - lr: 6.3096e-23
# Epoch 98/200
# 128/128 [==============================] - 35s 275ms/step - loss: 1.3126 - acuracia: 0.7448 - precisão: 0.3639 - recall: 0.0281 - auc: 0.6533 - f1_score: 0.0510 - val_loss: 1.2300 - val_acuracia: 0.7500 - val_precisão: 0.0000e+00 - val_recall: 0.0000e+00 - val_auc: 0.7485 - val_f1_score: 0.0000e+00 - lr: 3.9811e-23
# Epoch 99/200
# 128/128 [==============================] - 35s 275ms/step - loss: 1.3002 - acuracia: 0.7452 - precisão: 0.3853 - recall: 0.0320 - auc: 0.6642 - f1_score: 0.0576 - val_loss: 1.2300 - val_acuracia: 0.7500 - val_precisão: 0.0000e+00 - val_recall: 0.0000e+00 - val_auc: 0.7485 - val_f1_score: 0.0000e+00 - lr: 2.5119e-23
# Epoch 100/200
# 128/128 [==============================] - 35s 275ms/step - loss: 1.3098 - acuracia: 0.7444 - precisão: 0.3673 - recall: 0.0308 - auc: 0.6569 - f1_score: 0.0558 - val_loss: 1.2300 - val_acuracia: 0.7500 - val_precisão: 0.0000e+00 - val_recall: 0.0000e+00 - val_auc: 0.7485 - val_f1_score: 0.0000e+00 - lr: 1.5849e-23
# Epoch 101/200
# 128/128 [==============================] - 35s 275ms/step - loss: 1.3225 - acuracia: 0.7437 - precisão: 0.3516 - recall: 0.0298 - auc: 0.6451 - f1_score: 0.0536 - val_loss: 1.2300 - val_acuracia: 0.7500 - val_precisão: 0.0000e+00 - val_recall: 0.0000e+00 - val_auc: 0.7485 - val_f1_score: 0.0000e+00 - lr: 1.0000e-23
# Epoch 102/200
# 128/128 [==============================] - 35s 274ms/step - loss: 1.3176 - acuracia: 0.7419 - precisão: 0.3158 - recall: 0.0278 - auc: 0.6510 - f1_score: 0.0503 - val_loss: 1.2300 - val_acuracia: 0.7500 - val_precisão: 0.0000e+00 - val_recall: 0.0000e+00 - val_auc: 0.7485 - val_f1_score: 0.0000e+00 - lr: 6.3096e-24
# Epoch 103/200
# 128/128 [==============================] - 35s 275ms/step - loss: 1.3111 - acuracia: 0.7452 - precisão: 0.3811 - recall: 0.0305 - auc: 0.6542 - f1_score: 0.0551 - val_loss: 1.2300 - val_acuracia: 0.7500 - val_precisão: 0.0000e+00 - val_recall: 0.0000e+00 - val_auc: 0.7485 - val_f1_score: 0.0000e+00 - lr: 3.9811e-24
# Epoch 104/200
# 128/128 [==============================] - 35s 274ms/step - loss: 1.3023 - acuracia: 0.7455 - precisão: 0.3836 - recall: 0.0298 - auc: 0.6610 - f1_score: 0.0541 - val_loss: 1.2300 - val_acuracia: 0.7500 - val_precisão: 0.0000e+00 - val_recall: 0.0000e+00 - val_auc: 0.7485 - val_f1_score: 0.0000e+00 - lr: 2.5119e-24
# Epoch 105/200
# 128/128 [==============================] - 35s 275ms/step - loss: 1.3135 - acuracia: 0.7442 - precisão: 0.3631 - recall: 0.0308 - auc: 0.6510 - f1_score: 0.0552 - val_loss: 1.2300 - val_acuracia: 0.7500 - val_precisão: 0.0000e+00 - val_recall: 0.0000e+00 - val_auc: 0.7485 - val_f1_score: 0.0000e+00 - lr: 1.5849e-24
# Epoch 106/200
# 128/128 [==============================] - 35s 274ms/step - loss: 1.3138 - acuracia: 0.7454 - precisão: 0.3887 - recall: 0.0320 - auc: 0.6525 - f1_score: 0.0575 - val_loss: 1.2300 - val_acuracia: 0.7500 - val_precisão: 0.0000e+00 - val_recall: 0.0000e+00 - val_auc: 0.7485 - val_f1_score: 0.0000e+00 - lr: 1.0000e-24
# Epoch 107/200
# 128/128 [==============================] - 35s 274ms/step - loss: 1.3134 - acuracia: 0.7452 - precisão: 0.3774 - recall: 0.0293 - auc: 0.6527 - f1_score: 0.0534 - val_loss: 1.2300 - val_acuracia: 0.7500 - val_precisão: 0.0000e+00 - val_recall: 0.0000e+00 - val_auc: 0.7485 - val_f1_score: 0.0000e+00 - lr: 6.3096e-25
# Epoch 108/200
# 128/128 [==============================] - 35s 274ms/step - loss: 1.2999 - acuracia: 0.7460 - precisão: 0.3988 - recall: 0.0317 - auc: 0.6625 - f1_score: 0.0570 - val_loss: 1.2300 - val_acuracia: 0.7500 - val_precisão: 0.0000e+00 - val_recall: 0.0000e+00 - val_auc: 0.7485 - val_f1_score: 0.0000e+00 - lr: 3.9811e-25
# Epoch 109/200
# 128/128 [==============================] - 35s 274ms/step - loss: 1.3059 - acuracia: 0.7441 - precisão: 0.3420 - recall: 0.0256 - auc: 0.6571 - f1_score: 0.0468 - val_loss: 1.2300 - val_acuracia: 0.7500 - val_precisão: 0.0000e+00 - val_recall: 0.0000e+00 - val_auc: 0.7485 - val_f1_score: 0.0000e+00 - lr: 2.5119e-25
# Epoch 110/200
# 128/128 [==============================] - 35s 274ms/step - loss: 1.3141 - acuracia: 0.7460 - precisão: 0.3994 - recall: 0.0320 - auc: 0.6520 - f1_score: 0.0580 - val_loss: 1.2300 - val_acuracia: 0.7500 - val_precisão: 0.0000e+00 - val_recall: 0.0000e+00 - val_auc: 0.7485 - val_f1_score: 0.0000e+00 - lr: 1.5849e-25
# Epoch 111/200
# 128/128 [==============================] - 35s 274ms/step - loss: 1.3200 - acuracia: 0.7429 - precisão: 0.3324 - recall: 0.0283 - auc: 0.6481 - f1_score: 0.0509 - val_loss: 1.2300 - val_acuracia: 0.7500 - val_precisão: 0.0000e+00 - val_recall: 0.0000e+00 - val_auc: 0.7485 - val_f1_score: 0.0000e+00 - lr: 1.0000e-25
# Epoch 112/200
# 128/128 [==============================] - 35s 275ms/step - loss: 1.3081 - acuracia: 0.7467 - precisão: 0.4206 - recall: 0.0349 - auc: 0.6566 - f1_score: 0.0628 - val_loss: 1.2300 - val_acuracia: 0.7500 - val_precisão: 0.0000e+00 - val_recall: 0.0000e+00 - val_auc: 0.7485 - val_f1_score: 0.0000e+00 - lr: 6.3096e-26
# Epoch 113/200
# 128/128 [==============================] - 35s 275ms/step - loss: 1.3147 - acuracia: 0.7465 - precisão: 0.4127 - recall: 0.0334 - auc: 0.6505 - f1_score: 0.0602 - val_loss: 1.2300 - val_acuracia: 0.7500 - val_precisão: 0.0000e+00 - val_recall: 0.0000e+00 - val_auc: 0.7485 - val_f1_score: 0.0000e+00 - lr: 3.9811e-26
# Epoch 114/200
# 128/128 [==============================] - 35s 275ms/step - loss: 1.3096 - acuracia: 0.7440 - precisão: 0.3576 - recall: 0.0300 - auc: 0.6557 - f1_score: 0.0539 - val_loss: 1.2300 - val_acuracia: 0.7500 - val_precisão: 0.0000e+00 - val_recall: 0.0000e+00 - val_auc: 0.7485 - val_f1_score: 0.0000e+00 - lr: 2.5119e-26
# Epoch 115/200
# 128/128 [==============================] - 35s 275ms/step - loss: 1.3123 - acuracia: 0.7469 - precisão: 0.4225 - recall: 0.0339 - auc: 0.6533 - f1_score: 0.0610 - val_loss: 1.2300 - val_acuracia: 0.7500 - val_precisão: 0.0000e+00 - val_recall: 0.0000e+00 - val_auc: 0.7485 - val_f1_score: 0.0000e+00 - lr: 1.5849e-26
# Epoch 116/200
# 128/128 [==============================] - 35s 275ms/step - loss: 1.3017 - acuracia: 0.7453 - precisão: 0.3754 - recall: 0.0283 - auc: 0.6609 - f1_score: 0.0514 - val_loss: 1.2300 - val_acuracia: 0.7500 - val_precisão: 0.0000e+00 - val_recall: 0.0000e+00 - val_auc: 0.7485 - val_f1_score: 0.0000e+00 - lr: 1.0000e-26
# Epoch 117/200
# 128/128 [==============================] - 35s 275ms/step - loss: 1.3037 - acuracia: 0.7455 - precisão: 0.3918 - recall: 0.0327 - auc: 0.6594 - f1_score: 0.0585 - val_loss: 1.2300 - val_acuracia: 0.7500 - val_precisão: 0.0000e+00 - val_recall: 0.0000e+00 - val_auc: 0.7485 - val_f1_score: 0.0000e+00 - lr: 6.3096e-27
# Epoch 118/200
# 128/128 [==============================] - 35s 275ms/step - loss: 1.3062 - acuracia: 0.7438 - precisão: 0.3473 - recall: 0.0283 - auc: 0.6569 - f1_score: 0.0510 - val_loss: 1.2300 - val_acuracia: 0.7500 - val_precisão: 0.0000e+00 - val_recall: 0.0000e+00 - val_auc: 0.7485 - val_f1_score: 0.0000e+00 - lr: 3.9811e-27
# Epoch 119/200
# 128/128 [==============================] - 35s 275ms/step - loss: 1.3201 - acuracia: 0.7443 - precisão: 0.3514 - recall: 0.0269 - auc: 0.6465 - f1_score: 0.0485 - val_loss: 1.2300 - val_acuracia: 0.7500 - val_precisão: 0.0000e+00 - val_recall: 0.0000e+00 - val_auc: 0.7485 - val_f1_score: 0.0000e+00 - lr: 2.5119e-27
# Epoch 120/200
# 128/128 [==============================] - 35s 275ms/step - loss: 1.3045 - acuracia: 0.7451 - precisão: 0.3864 - recall: 0.0332 - auc: 0.6599 - f1_score: 0.0599 - val_loss: 1.2300 - val_acuracia: 0.7500 - val_precisão: 0.0000e+00 - val_recall: 0.0000e+00 - val_auc: 0.7485 - val_f1_score: 0.0000e+00 - lr: 1.5849e-27
# Epoch 121/200
# 128/128 [==============================] - 35s 275ms/step - loss: 1.3070 - acuracia: 0.7471 - precisão: 0.4281 - recall: 0.0349 - auc: 0.6578 - f1_score: 0.0631 - val_loss: 1.2300 - val_acuracia: 0.7500 - val_precisão: 0.0000e+00 - val_recall: 0.0000e+00 - val_auc: 0.7485 - val_f1_score: 0.0000e+00 - lr: 1.0000e-27
# Epoch 122/200
# 128/128 [==============================] - 35s 275ms/step - loss: 1.3170 - acuracia: 0.7452 - precisão: 0.3839 - recall: 0.0315 - auc: 0.6492 - f1_score: 0.0560 - val_loss: 1.2300 - val_acuracia: 0.7500 - val_precisão: 0.0000e+00 - val_recall: 0.0000e+00 - val_auc: 0.7485 - val_f1_score: 0.0000e+00 - lr: 6.3096e-28
# Epoch 123/200
# 128/128 [==============================] - 35s 275ms/step - loss: 1.3139 - acuracia: 0.7458 - precisão: 0.3957 - recall: 0.0315 - auc: 0.6532 - f1_score: 0.0568 - val_loss: 1.2300 - val_acuracia: 0.7500 - val_precisão: 0.0000e+00 - val_recall: 0.0000e+00 - val_auc: 0.7485 - val_f1_score: 0.0000e+00 - lr: 3.9811e-28
# Epoch 124/200
# 128/128 [==============================] - 35s 275ms/step - loss: 1.3119 - acuracia: 0.7433 - precisão: 0.3392 - recall: 0.0283 - auc: 0.6557 - f1_score: 0.0510 - val_loss: 1.2300 - val_acuracia: 0.7500 - val_precisão: 0.0000e+00 - val_recall: 0.0000e+00 - val_auc: 0.7485 - val_f1_score: 0.0000e+00 - lr: 2.5119e-28
# Epoch 125/200
# 128/128 [==============================] - 35s 275ms/step - loss: 1.3158 - acuracia: 0.7456 - precisão: 0.3941 - recall: 0.0327 - auc: 0.6502 - f1_score: 0.0591 - val_loss: 1.2300 - val_acuracia: 0.7500 - val_precisão: 0.0000e+00 - val_recall: 0.0000e+00 - val_auc: 0.7485 - val_f1_score: 0.0000e+00 - lr: 1.5849e-28
# Epoch 126/200
# 128/128 [==============================] - 35s 275ms/step - loss: 1.3157 - acuracia: 0.7446 - precisão: 0.3725 - recall: 0.0317 - auc: 0.6516 - f1_score: 0.0565 - val_loss: 1.2300 - val_acuracia: 0.7500 - val_precisão: 0.0000e+00 - val_recall: 0.0000e+00 - val_auc: 0.7485 - val_f1_score: 0.0000e+00 - lr: 1.0000e-28
# Epoch 127/200
# 128/128 [==============================] - 35s 275ms/step - loss: 1.3008 - acuracia: 0.7454 - precisão: 0.3876 - recall: 0.0320 - auc: 0.6634 - f1_score: 0.0578 - val_loss: 1.2300 - val_acuracia: 0.7500 - val_precisão: 0.0000e+00 - val_recall: 0.0000e+00 - val_auc: 0.7485 - val_f1_score: 0.0000e+00 - lr: 6.3096e-29
# Epoch 128/200
# 128/128 [==============================] - 35s 275ms/step - loss: 1.3033 - acuracia: 0.7450 - precisão: 0.3848 - recall: 0.0334 - auc: 0.6597 - f1_score: 0.0604 - val_loss: 1.2300 - val_acuracia: 0.7500 - val_precisão: 0.0000e+00 - val_recall: 0.0000e+00 - val_auc: 0.7485 - val_f1_score: 0.0000e+00 - lr: 3.9811e-29
# Epoch 129/200
# 128/128 [==============================] - 35s 275ms/step - loss: 1.3221 - acuracia: 0.7443 - precisão: 0.3531 - recall: 0.0276 - auc: 0.6449 - f1_score: 0.0502 - val_loss: 1.2300 - val_acuracia: 0.7500 - val_precisão: 0.0000e+00 - val_recall: 0.0000e+00 - val_auc: 0.7485 - val_f1_score: 0.0000e+00 - lr: 2.5119e-29
# Epoch 130/200
# 128/128 [==============================] - 35s 275ms/step - loss: 1.3066 - acuracia: 0.7439 - precisão: 0.3466 - recall: 0.0276 - auc: 0.6564 - f1_score: 0.0500 - val_loss: 1.2300 - val_acuracia: 0.7500 - val_precisão: 0.0000e+00 - val_recall: 0.0000e+00 - val_auc: 0.7485 - val_f1_score: 0.0000e+00 - lr: 1.5849e-29
# Epoch 131/200
# 128/128 [==============================] - 35s 275ms/step - loss: 1.3176 - acuracia: 0.7441 - precisão: 0.3667 - recall: 0.0322 - auc: 0.6485 - f1_score: 0.0578 - val_loss: 1.2300 - val_acuracia: 0.7500 - val_precisão: 0.0000e+00 - val_recall: 0.0000e+00 - val_auc: 0.7485 - val_f1_score: 0.0000e+00 - lr: 1.0000e-29
# Epoch 132/200
# 128/128 [==============================] - 35s 275ms/step - loss: 1.3029 - acuracia: 0.7455 - precisão: 0.3931 - recall: 0.0332 - auc: 0.6598 - f1_score: 0.0598 - val_loss: 1.2300 - val_acuracia: 0.7500 - val_precisão: 0.0000e+00 - val_recall: 0.0000e+00 - val_auc: 0.7485 - val_f1_score: 0.0000e+00 - lr: 6.3096e-30
# Epoch 133/200
# 128/128 [==============================] - 35s 275ms/step - loss: 1.3089 - acuracia: 0.7441 - precisão: 0.3508 - recall: 0.0278 - auc: 0.6561 - f1_score: 0.0504 - val_loss: 1.2300 - val_acuracia: 0.7500 - val_precisão: 0.0000e+00 - val_recall: 0.0000e+00 - val_auc: 0.7485 - val_f1_score: 0.0000e+00 - lr: 3.9811e-30
# Epoch 134/200
# 128/128 [==============================] - 35s 275ms/step - loss: 1.3131 - acuracia: 0.7450 - precisão: 0.3711 - recall: 0.0288 - auc: 0.6533 - f1_score: 0.0523 - val_loss: 1.2300 - val_acuracia: 0.7500 - val_precisão: 0.0000e+00 - val_recall: 0.0000e+00 - val_auc: 0.7485 - val_f1_score: 0.0000e+00 - lr: 2.5119e-30
# Epoch 135/200
# 128/128 [==============================] - 35s 276ms/step - loss: 1.3169 - acuracia: 0.7451 - precisão: 0.3844 - recall: 0.0325 - auc: 0.6495 - f1_score: 0.0585 - val_loss: 1.2300 - val_acuracia: 0.7500 - val_precisão: 0.0000e+00 - val_recall: 0.0000e+00 - val_auc: 0.7485 - val_f1_score: 0.0000e+00 - lr: 1.5849e-30
# Epoch 136/200
# 128/128 [==============================] - 35s 276ms/step - loss: 1.3101 - acuracia: 0.7468 - precisão: 0.4249 - recall: 0.0359 - auc: 0.6547 - f1_score: 0.0645 - val_loss: 1.2300 - val_acuracia: 0.7500 - val_precisão: 0.0000e+00 - val_recall: 0.0000e+00 - val_auc: 0.7485 - val_f1_score: 0.0000e+00 - lr: 1.0000e-30
# Epoch 137/200
# 128/128 [==============================] - 35s 276ms/step - loss: 1.2996 - acuracia: 0.7471 - precisão: 0.4268 - recall: 0.0342 - auc: 0.6626 - f1_score: 0.0619 - val_loss: 1.2300 - val_acuracia: 0.7500 - val_precisão: 0.0000e+00 - val_recall: 0.0000e+00 - val_auc: 0.7485 - val_f1_score: 0.0000e+00 - lr: 6.3096e-31
# Epoch 138/200
# 128/128 [==============================] - 35s 275ms/step - loss: 1.3047 - acuracia: 0.7457 - precisão: 0.3933 - recall: 0.0315 - auc: 0.6603 - f1_score: 0.0568 - val_loss: 1.2300 - val_acuracia: 0.7500 - val_precisão: 0.0000e+00 - val_recall: 0.0000e+00 - val_auc: 0.7485 - val_f1_score: 0.0000e+00 - lr: 3.9811e-31
# Epoch 139/200
# 128/128 [==============================] - 35s 275ms/step - loss: 1.3033 - acuracia: 0.7468 - precisão: 0.4153 - recall: 0.0317 - auc: 0.6592 - f1_score: 0.0576 - val_loss: 1.2300 - val_acuracia: 0.7500 - val_precisão: 0.0000e+00 - val_recall: 0.0000e+00 - val_auc: 0.7485 - val_f1_score: 0.0000e+00 - lr: 2.5119e-31
# Epoch 140/200
# 128/128 [==============================] - 35s 275ms/step - loss: 1.3130 - acuracia: 0.7455 - precisão: 0.3955 - recall: 0.0342 - auc: 0.6531 - f1_score: 0.0616 - val_loss: 1.2300 - val_acuracia: 0.7500 - val_precisão: 0.0000e+00 - val_recall: 0.0000e+00 - val_auc: 0.7485 - val_f1_score: 0.0000e+00 - lr: 1.5849e-31
# Epoch 141/200
# 128/128 [==============================] - 35s 276ms/step - loss: 1.3074 - acuracia: 0.7444 - precisão: 0.3658 - recall: 0.0303 - auc: 0.6577 - f1_score: 0.0543 - val_loss: 1.2300 - val_acuracia: 0.7500 - val_precisão: 0.0000e+00 - val_recall: 0.0000e+00 - val_auc: 0.7485 - val_f1_score: 0.0000e+00 - lr: 1.0000e-31
# Epoch 142/200
# 128/128 [==============================] - 35s 276ms/step - loss: 1.3073 - acuracia: 0.7478 - precisão: 0.4474 - recall: 0.0374 - auc: 0.6573 - f1_score: 0.0670 - val_loss: 1.2300 - val_acuracia: 0.7500 - val_precisão: 0.0000e+00 - val_recall: 0.0000e+00 - val_auc: 0.7485 - val_f1_score: 0.0000e+00 - lr: 6.3096e-32
# Epoch 143/200
# 128/128 [==============================] - 35s 276ms/step - loss: 1.3126 - acuracia: 0.7444 - precisão: 0.3614 - recall: 0.0293 - auc: 0.6551 - f1_score: 0.0529 - val_loss: 1.2300 - val_acuracia: 0.7500 - val_precisão: 0.0000e+00 - val_recall: 0.0000e+00 - val_auc: 0.7485 - val_f1_score: 0.0000e+00 - lr: 3.9811e-32
# Epoch 144/200
# 128/128 [==============================] - 35s 275ms/step - loss: 1.3120 - acuracia: 0.7444 - precisão: 0.3658 - recall: 0.0303 - auc: 0.6531 - f1_score: 0.0545 - val_loss: 1.2300 - val_acuracia: 0.7500 - val_precisão: 0.0000e+00 - val_recall: 0.0000e+00 - val_auc: 0.7485 - val_f1_score: 0.0000e+00 - lr: 2.5119e-32
# Epoch 145/200
# 128/128 [==============================] - 35s 275ms/step - loss: 1.3085 - acuracia: 0.7463 - precisão: 0.4038 - recall: 0.0312 - auc: 0.6551 - f1_score: 0.0564 - val_loss: 1.2300 - val_acuracia: 0.7500 - val_precisão: 0.0000e+00 - val_recall: 0.0000e+00 - val_auc: 0.7485 - val_f1_score: 0.0000e+00 - lr: 1.5849e-32
# Epoch 146/200
# ...
# Epoch 153/200
# 128/128 [==============================] - 35s 276ms/step - loss: 1.3200 - acuracia: 0.7457 - precisão: 0.3859 - recall: 0.0293 - auc: 0.6468 - f1_score: 0.0530 - val_loss: 1.2300 - val_acuracia: 0.7500 - val_precisão: 0.0000e+00 - val_recall: 0.0000e+00 - val_auc: 0.7485 - val_f1_score: 0.0000e+00 - lr: 3.9811e-34
# Epoch 154/200
# 128/128 [==============================] - 35s 275ms/step - loss: 1.3177 - acuracia: 0.7433 - precisão: 0.3281 - recall: 0.0254 - auc: 0.6487 - f1_score: 0.0461 - val_loss: 1.2300 - val_acuracia: 0.7500 - val_precisão: 0.0000e+00 - val_recall: 0.0000e+00 - val_auc: 0.7485 - val_f1_score: 0.0000e+00 - lr: 2.5119e-34
# Epoch 155/200
# 128/128 [==============================] - 35s 276ms/step - loss: 1.3070 - acuracia: 0.7448 - precisão: 0.3659 - recall: 0.0283 - auc: 0.6580 - f1_score: 0.0517 - val_loss: 1.2300 - val_acuracia: 0.7500 - val_precisão: 0.0000e+00 - val_recall: 0.0000e+00 - val_auc: 0.7485 - val_f1_score: 0.0000e+00 - lr: 1.5849e-34
# Epoch 156/200
# 128/128 [==============================] - 35s 276ms/step - loss: 1.3163 - acuracia: 0.7452 - precisão: 0.3853 - recall: 0.0320 - auc: 0.6490 - f1_score: 0.0578 - val_loss: 1.2300 - val_acuracia: 0.7500 - val_precisão: 0.0000e+00 - val_recall: 0.0000e+00 - val_auc: 0.7485 - val_f1_score: 0.0000e+00 - lr: 1.0000e-34
# Epoch 157/200
# 128/128 [==============================] - 35s 276ms/step - loss: 1.3147 - acuracia: 0.7468 - precisão: 0.4204 - recall: 0.0342 - auc: 0.6489 - f1_score: 0.0617 - val_loss: 1.2300 - val_acuracia: 0.7500 - val_precisão: 0.0000e+00 - val_recall: 0.0000e+00 - val_auc: 0.7485 - val_f1_score: 0.0000e+00 - lr: 6.3096e-35
# Epoch 158/200
# 128/128 [==============================] - 35s 276ms/step - loss: 1.3118 - acuracia: 0.7454 - precisão: 0.3790 - recall: 0.0291 - auc: 0.6536 - f1_score: 0.0526 - val_loss: 1.2300 - val_acuracia: 0.7500 - val_precisão: 0.0000e+00 - val_recall: 0.0000e+00 - val_auc: 0.7485 - val_f1_score: 0.0000e+00 - lr: 3.9811e-35
# Epoch 159/200
# 128/128 [==============================] - 35s 275ms/step - loss: 1.3159 - acuracia: 0.7426 - precisão: 0.3205 - recall: 0.0264 - auc: 0.6505 - f1_score: 0.0481 - val_loss: 1.2300 - val_acuracia: 0.7500 - val_precisão: 0.0000e+00 - val_recall: 0.0000e+00 - val_auc: 0.7485 - val_f1_score: 0.0000e+00 - lr: 2.5119e-35
# Epoch 160/200
# 128/128 [==============================] - 35s 276ms/step - loss: 1.3053 - acuracia: 0.7460 - precisão: 0.3935 - recall: 0.0298 - auc: 0.6577 - f1_score: 0.0541 - val_loss: 1.2300 - val_acuracia: 0.7500 - val_precisão: 0.0000e+00 - val_recall: 0.0000e+00 - val_auc: 0.7485 - val_f1_score: 0.0000e+00 - lr: 1.5849e-35
# Epoch 161/200
# 128/128 [==============================] - 35s 276ms/step - loss: 1.3134 - acuracia: 0.7449 - precisão: 0.3852 - recall: 0.0344 - auc: 0.6537 - f1_score: 0.0616 - val_loss: 1.2300 - val_acuracia: 0.7500 - val_precisão: 0.0000e+00 - val_recall: 0.0000e+00 - val_auc: 0.7485 - val_f1_score: 0.0000e+00 - lr: 1.0000e-35
# Epoch 162/200
# 128/128 [==============================] - 35s 275ms/step - loss: 1.3148 - acuracia: 0.7457 - precisão: 0.3892 - recall: 0.0300 - auc: 0.6526 - f1_score: 0.0544 - val_loss: 1.2300 - val_acuracia: 0.7500 - val_precisão: 0.0000e+00 - val_recall: 0.0000e+00 - val_auc: 0.7485 - val_f1_score: 0.0000e+00 - lr: 6.3096e-36
# Epoch 163/200
# 128/128 [==============================] - 35s 276ms/step - loss: 1.3080 - acuracia: 0.7447 - precisão: 0.3653 - recall: 0.0288 - auc: 0.6569 - f1_score: 0.0523 - val_loss: 1.2300 - val_acuracia: 0.7500 - val_precisão: 0.0000e+00 - val_recall: 0.0000e+00 - val_auc: 0.7485 - val_f1_score: 0.0000e+00 - lr: 3.9811e-36
# Epoch 164/200
# 128/128 [==============================] - 35s 276ms/step - loss: 1.3173 - acuracia: 0.7449 - precisão: 0.3696 - recall: 0.0291 - auc: 0.6465 - f1_score: 0.0526 - val_loss: 1.2300 - val_acuracia: 0.7500 - val_precisão: 0.0000e+00 - val_recall: 0.0000e+00 - val_auc: 0.7485 - val_f1_score: 0.0000e+00 - lr: 2.5119e-36
# Epoch 165/200
# 128/128 [==============================] - 35s 276ms/step - loss: 1.3077 - acuracia: 0.7458 - precisão: 0.3951 - recall: 0.0312 - auc: 0.6568 - f1_score: 0.0570 - val_loss: 1.2300 - val_acuracia: 0.7500 - val_precisão: 0.0000e+00 - val_recall: 0.0000e+00 - val_auc: 0.7485 - val_f1_score: 0.0000e+00 - lr: 1.5849e-36
# Epoch 166/200
# 128/128 [==============================] - 35s 276ms/step - loss: 1.3114 - acuracia: 0.7443 - precisão: 0.3723 - recall: 0.0334 - auc: 0.6539 - f1_score: 0.0596 - val_loss: 1.2300 - val_acuracia: 0.7500 - val_precisão: 0.0000e+00 - val_recall: 0.0000e+00 - val_auc: 0.7485 - val_f1_score: 0.0000e+00 - lr: 1.0000e-36
# Epoch 167/200
# 128/128 [==============================] - 35s 276ms/step - loss: 1.3187 - acuracia: 0.7424 - precisão: 0.3156 - recall: 0.0261 - auc: 0.6472 - f1_score: 0.0469 - val_loss: 1.2300 - val_acuracia: 0.7500 - val_precisão: 0.0000e+00 - val_recall: 0.0000e+00 - val_auc: 0.7485 - val_f1_score: 0.0000e+00 - lr: 6.3096e-37
# Epoch 168/200
# 128/128 [==============================] - 35s 276ms/step - loss: 1.3048 - acuracia: 0.7464 - precisão: 0.4160 - recall: 0.0356 - auc: 0.6590 - f1_score: 0.0639 - val_loss: 1.2300 - val_acuracia: 0.7500 - val_precisão: 0.0000e+00 - val_recall: 0.0000e+00 - val_auc: 0.7485 - val_f1_score: 0.0000e+00 - lr: 3.9811e-37
# Epoch 169/200
# 128/128 [==============================] - 35s 276ms/step - loss: 1.3195 - acuracia: 0.7446 - precisão: 0.3522 - recall: 0.0259 - auc: 0.6458 - f1_score: 0.0473 - val_loss: 1.2300 - val_acuracia: 0.7500 - val_precisão: 0.0000e+00 - val_recall: 0.0000e+00 - val_auc: 0.7485 - val_f1_score: 0.0000e+00 - lr: 2.5119e-37
# Epoch 170/200
# 128/128 [==============================] - 35s 276ms/step - loss: 1.3168 - acuracia: 0.7455 - precisão: 0.3791 - recall: 0.0283 - auc: 0.6491 - f1_score: 0.0516 - val_loss: 1.2300 - val_acuracia: 0.7500 - val_precisão: 0.0000e+00 - val_recall: 0.0000e+00 - val_auc: 0.7485 - val_f1_score: 0.0000e+00 - lr: 1.5849e-37
# Epoch 171/200
# 128/128 [==============================] - 35s 276ms/step - loss: 1.3087 - acuracia: 0.7451 - precisão: 0.3636 - recall: 0.0264 - auc: 0.6545 - f1_score: 0.0476 - val_loss: 1.2300 - val_acuracia: 0.7500 - val_precisão: 0.0000e+00 - val_recall: 0.0000e+00 - val_auc: 0.7485 - val_f1_score: 0.0000e+00 - lr: 1.0000e-37
# Epoch 172/200
# 128/128 [==============================] - 35s 276ms/step - loss: 1.3062 - acuracia: 0.7462 - precisão: 0.4019 - recall: 0.0315 - auc: 0.6578 - f1_score: 0.0569 - val_loss: 1.2300 - val_acuracia: 0.7500 - val_precisão: 0.0000e+00 - val_recall: 0.0000e+00 - val_auc: 0.7485 - val_f1_score: 0.0000e+00 - lr: 6.3096e-38
# Epoch 173/200
# 128/128 [==============================] - 35s 276ms/step - loss: 1.3168 - acuracia: 0.7435 - precisão: 0.3432 - recall: 0.0283 - auc: 0.6489 - f1_score: 0.0509 - val_loss: 1.2300 - val_acuracia: 0.7500 - val_precisão: 0.0000e+00 - val_recall: 0.0000e+00 - val_auc: 0.7485 - val_f1_score: 0.0000e+00 - lr: 3.9811e-38
# Epoch 174/200
# 128/128 [==============================] - 35s 276ms/step - loss: 1.3132 - acuracia: 0.7444 - precisão: 0.3658 - recall: 0.0303 - auc: 0.6514 - f1_score: 0.0546 - val_loss: 1.2300 - val_acuracia: 0.7500 - val_precisão: 0.0000e+00 - val_recall: 0.0000e+00 - val_auc: 0.7485 - val_f1_score: 0.0000e+00 - lr: 2.5119e-38
# Epoch 175/200
# 128/128 [==============================] - 35s 276ms/step - loss: 1.3058 - acuracia: 0.7444 - precisão: 0.3642 - recall: 0.0298 - auc: 0.6590 - f1_score: 0.0537 - val_loss: 1.2300 - val_acuracia: 0.7500 - val_precisão: 0.0000e+00 - val_recall: 0.0000e+00 - val_auc: 0.7485 - val_f1_score: 0.0000e+00 - lr: 1.5849e-38
# Epoch 176/200
# 128/128 [==============================] - 35s 276ms/step - loss: 1.3043 - acuracia: 0.7455 - precisão: 0.3834 - recall: 0.0293 - auc: 0.6571 - f1_score: 0.0533 - val_loss: 1.2300 - val_acuracia: 0.7500 - val_precisão: 0.0000e+00 - val_recall: 0.0000e+00 - val_auc: 0.7485 - val_f1_score: 0.0000e+00 - lr: 1.0000e-38
# Epoch 177/200
# 128/128 [==============================] - 35s 276ms/step - loss: 1.2974 - acuracia: 0.7475 - precisão: 0.4381 - recall: 0.0354 - auc: 0.6653 - f1_score: 0.0634 - val_loss: 1.2300 - val_acuracia: 0.7500 - val_precisão: 0.0000e+00 - val_recall: 0.0000e+00 - val_auc: 0.7485 - val_f1_score: 0.0000e+00 - lr: 6.3096e-39
# Epoch 178/200
# 128/128 [==============================] - 35s 276ms/step - loss: 1.3046 - acuracia: 0.7452 - precisão: 0.3881 - recall: 0.0334 - auc: 0.6596 - f1_score: 0.0603 - val_loss: 1.2300 - val_acuracia: 0.7500 - val_precisão: 0.0000e+00 - val_recall: 0.0000e+00 - val_auc: 0.7485 - val_f1_score: 0.0000e+00 - lr: 3.9811e-39
# Epoch 179/200
# 128/128 [==============================] - 35s 276ms/step - loss: 1.3081 - acuracia: 0.7430 - precisão: 0.3408 - recall: 0.0298 - auc: 0.6556 - f1_score: 0.0535 - val_loss: 1.2300 - val_acuracia: 0.7500 - val_precisão: 0.0000e+00 - val_recall: 0.0000e+00 - val_auc: 0.7485 - val_f1_score: 0.0000e+00 - lr: 2.5119e-39
# Epoch 180/200
# 128/128 [==============================] - 35s 276ms/step - loss: 1.3156 - acuracia: 0.7449 - precisão: 0.3790 - recall: 0.0317 - auc: 0.6514 - f1_score: 0.0566 - val_loss: 1.2300 - val_acuracia: 0.7500 - val_precisão: 0.0000e+00 - val_recall: 0.0000e+00 - val_auc: 0.7485 - val_f1_score: 0.0000e+00 - lr: 1.5849e-39
# Epoch 181/200
# 128/128 [==============================] - 35s 276ms/step - loss: 1.3076 - acuracia: 0.7441 - precisão: 0.3621 - recall: 0.0308 - auc: 0.6576 - f1_score: 0.0555 - val_loss: 1.2300 - val_acuracia: 0.7500 - val_precisão: 0.0000e+00 - val_recall: 0.0000e+00 - val_auc: 0.7485 - val_f1_score: 0.0000e+00 - lr: 1.0000e-39
# Epoch 182/200
# 128/128 [==============================] - 35s 276ms/step - loss: 1.3051 - acuracia: 0.7444 - precisão: 0.3506 - recall: 0.0264 - auc: 0.6578 - f1_score: 0.0475 - val_loss: 1.2300 - val_acuracia: 0.7500 - val_precisão: 0.0000e+00 - val_recall: 0.0000e+00 - val_auc: 0.7485 - val_f1_score: 0.0000e+00 - lr: 6.3096e-40
# Epoch 183/200
# 128/128 [==============================] - 35s 276ms/step - loss: 1.3051 - acuracia: 0.7454 - precisão: 0.3774 - recall: 0.0286 - auc: 0.6601 - f1_score: 0.0517 - val_loss: 1.2300 - val_acuracia: 0.7500 - val_precisão: 0.0000e+00 - val_recall: 0.0000e+00 - val_auc: 0.7485 - val_f1_score: 0.0000e+00 - lr: 3.9811e-40
# Epoch 184/200
# 128/128 [==============================] - 35s 276ms/step - loss: 1.3077 - acuracia: 0.7472 - precisão: 0.4281 - recall: 0.0334 - auc: 0.6555 - f1_score: 0.0602 - val_loss: 1.2300 - val_acuracia: 0.7500 - val_precisão: 0.0000e+00 - val_recall: 0.0000e+00 - val_auc: 0.7485 - val_f1_score: 0.0000e+00 - lr: 2.5119e-40
# Epoch 185/200
# 128/128 [==============================] - 35s 276ms/step - loss: 1.3126 - acuracia: 0.7452 - precisão: 0.3792 - recall: 0.0303 - auc: 0.6532 - f1_score: 0.0548 - val_loss: 1.2300 - val_acuracia: 0.7500 - val_precisão: 0.0000e+00 - val_recall: 0.0000e+00 - val_auc: 0.7485 - val_f1_score: 0.0000e+00 - lr: 1.5849e-40
# Epoch 186/200
# 128/128 [==============================] - 35s 276ms/step - loss: 1.3080 - acuracia: 0.7443 - precisão: 0.3595 - recall: 0.0291 - auc: 0.6577 - f1_score: 0.0526 - val_loss: 1.2300 - val_acuracia: 0.7500 - val_precisão: 0.0000e+00 - val_recall: 0.0000e+00 - val_auc: 0.7485 - val_f1_score: 0.0000e+00 - lr: 9.9999e-41
# Epoch 187/200
# 128/128 [==============================] - 35s 275ms/step - loss: 1.3096 - acuracia: 0.7449 - precisão: 0.3735 - recall: 0.0303 - auc: 0.6535 - f1_score: 0.0546 - val_loss: 1.2300 - val_acuracia: 0.7500 - val_precisão: 0.0000e+00 - val_recall: 0.0000e+00 - val_auc: 0.7485 - val_f1_score: 0.0000e+00 - lr: 6.3096e-41
# Epoch 188/200
# 128/128 [==============================] - 35s 276ms/step - loss: 1.3094 - acuracia: 0.7461 - precisão: 0.4059 - recall: 0.0337 - auc: 0.6537 - f1_score: 0.0609 - val_loss: 1.2300 - val_acuracia: 0.7500 - val_precisão: 0.0000e+00 - val_recall: 0.0000e+00 - val_auc: 0.7485 - val_f1_score: 0.0000e+00 - lr: 3.9811e-41
# Epoch 189/200
# 128/128 [==============================] - 35s 276ms/step - loss: 1.3126 - acuracia: 0.7443 - precisão: 0.3560 - recall: 0.0281 - auc: 0.6560 - f1_score: 0.0511 - val_loss: 1.2300 - val_acuracia: 0.7500 - val_precisão: 0.0000e+00 - val_recall: 0.0000e+00 - val_auc: 0.7485 - val_f1_score: 0.0000e+00 - lr: 2.5118e-41
# Epoch 190/200
# 128/128 [==============================] - 35s 277ms/step - loss: 1.3099 - acuracia: 0.7457 - precisão: 0.3965 - recall: 0.0332 - auc: 0.6551 - f1_score: 0.0596 - val_loss: 1.2300 - val_acuracia: 0.7500 - val_precisão: 0.0000e+00 - val_recall: 0.0000e+00 - val_auc: 0.7485 - val_f1_score: 0.0000e+00 - lr: 1.5849e-41
# Epoch 191/200
# 128/128 [==============================] - 35s 276ms/step - loss: 1.3062 - acuracia: 0.7452 - precisão: 0.3898 - recall: 0.0337 - auc: 0.6573 - f1_score: 0.0607 - val_loss: 1.2300 - val_acuracia: 0.7500 - val_precisão: 0.0000e+00 - val_recall: 0.0000e+00 - val_auc: 0.7485 - val_f1_score: 0.0000e+00 - lr: 9.9997e-42
# Epoch 192/200
# 128/128 [==============================] - 35s 277ms/step - loss: 1.3157 - acuracia: 0.7435 - precisão: 0.3290 - recall: 0.0249 - auc: 0.6488 - f1_score: 0.0451 - val_loss: 1.2300 - val_acuracia: 0.7500 - val_precisão: 0.0000e+00 - val_recall: 0.0000e+00 - val_auc: 0.7485 - val_f1_score: 0.0000e+00 - lr: 6.3100e-42
# Epoch 193/200
# 128/128 [==============================] - 35s 276ms/step - loss: 1.3187 - acuracia: 0.7426 - precisão: 0.3266 - recall: 0.0278 - auc: 0.6479 - f1_score: 0.0502 - val_loss: 1.2300 - val_acuracia: 0.7500 - val_precisão: 0.0000e+00 - val_recall: 0.0000e+00 - val_auc: 0.7485 - val_f1_score: 0.0000e+00 - lr: 3.9811e-42
# Epoch 194/200
# 128/128 [==============================] - 35s 277ms/step - loss: 1.3106 - acuracia: 0.7446 - precisão: 0.3754 - recall: 0.0327 - auc: 0.6530 - f1_score: 0.0588 - val_loss: 1.2300 - val_acuracia: 0.7500 - val_precisão: 0.0000e+00 - val_recall: 0.0000e+00 - val_auc: 0.7485 - val_f1_score: 0.0000e+00 - lr: 2.5125e-42
# Epoch 195/200
# 128/128 [==============================] - 35s 276ms/step - loss: 1.3087 - acuracia: 0.7445 - precisão: 0.3539 - recall: 0.0266 - auc: 0.6556 - f1_score: 0.0483 - val_loss: 1.2300 - val_acuracia: 0.7500 - val_precisão: 0.0000e+00 - val_recall: 0.0000e+00 - val_auc: 0.7485 - val_f1_score: 0.0000e+00 - lr: 1.5849e-42
# Epoch 196/200
# 128/128 [==============================] - 35s 276ms/step - loss: 1.3126 - acuracia: 0.7458 - precisão: 0.3903 - recall: 0.0295 - auc: 0.6548 - f1_score: 0.0535 - val_loss: 1.2300 - val_acuracia: 0.7500 - val_precisão: 0.0000e+00 - val_recall: 0.0000e+00 - val_auc: 0.7485 - val_f1_score: 0.0000e+00 - lr: 1.0005e-42
# Epoch 197/200
# 128/128 [==============================] - 35s 276ms/step - loss: 1.3031 - acuracia: 0.7449 - precisão: 0.3814 - recall: 0.0330 - auc: 0.6595 - f1_score: 0.0591 - val_loss: 1.2300 - val_acuracia: 0.7500 - val_precisão: 0.0000e+00 - val_recall: 0.0000e+00 - val_auc: 0.7485 - val_f1_score: 0.0000e+00 - lr: 6.3058e-43
# Epoch 198/200
# 128/128 [==============================] - 35s 276ms/step - loss: 1.3042 - acuracia: 0.7459 - precisão: 0.3937 - recall: 0.0303 - auc: 0.6591 - f1_score: 0.0547 - val_loss: 1.2300 - val_acuracia: 0.7500 - val_precisão: 0.0000e+00 - val_recall: 0.0000e+00 - val_auc: 0.7485 - val_f1_score: 0.0000e+00 - lr: 3.9797e-43
# Epoch 199/200
# 128/128 [==============================] - 35s 276ms/step - loss: 1.3040 - acuracia: 0.7462 - precisão: 0.4043 - recall: 0.0320 - auc: 0.6607 - f1_score: 0.0578 - val_loss: 1.2300 - val_acuracia: 0.7500 - val_precisão: 0.0000e+00 - val_recall: 0.0000e+00 - val_auc: 0.7485 - val_f1_score: 0.0000e+00 - lr: 2.5083e-43
# Epoch 200/200
# 128/128 [==============================] - 35s 276ms/step - loss: 1.3076 - acuracia: 0.7472 - precisão: 0.4258 - recall: 0.0322 - auc: 0.6566 - f1_score: 0.0587 - val_loss: 1.2300 - val_acuracia: 0.7500 - val_precisão: 0.0000e+00 - val_recall: 0.0000e+00 - val_auc: 0.7485 - val_f1_score: 0.0000e+00 - lr: 1.5835e-43

# %%
def Train_Val_Plot(acc,val_acc,loss,val_loss,auc,val_auc,precision,val_precision,f1,val_f1):
    
    fig, (ax1, ax2,ax3,ax4,ax5) = plt.subplots(1,5, figsize= (20,5))
    fig.suptitle(" Metricas do modelo ")

    ax1.plot(range(1, len(acc) + 1), acc)
    ax1.plot(range(1, len(val_acc) + 1), val_acc)
    ax1.set_title('Acuracia')
    ax1.set_xlabel('Folds')
    ax1.set_ylabel('Acuracia')
    ax1.legend(['Treino', 'Teste'])


    ax2.plot(range(1, len(loss) + 1), loss)
    ax2.plot(range(1, len(val_loss) + 1), val_loss)
    ax2.set_title('Loss')
    ax2.set_xlabel('Folds')
    ax2.set_ylabel('Loss')
    ax1.legend(['Treino', 'Teste'])
    
    ax3.plot(range(1, len(auc) + 1), auc)
    ax3.plot(range(1, len(val_auc) + 1), val_auc)
    ax3.set_title('AUC')
    ax3.set_xlabel('Folds')
    ax3.set_ylabel('AUC')
    ax1.legend(['Treino', 'Teste'])
    
    ax4.plot(range(1, len(precision) + 1), precision)
    ax4.plot(range(1, len(val_precision) + 1), val_precision)
    ax4.set_title('Precisão')
    ax4.set_xlabel('Folds')
    ax4.set_ylabel('Precisão')
    ax1.legend(['Treino', 'Teste'])
    
    ax5.plot(range(1, len(f1) + 1), f1)
    ax5.plot(range(1, len(val_f1) + 1), val_f1)
    ax5.set_title('F1-score')
    ax5.set_xlabel('Folds')
    ax5.set_ylabel('F1 score')
    ax1.legend(['Treino', 'Teste'])


    plt.show()
    

Train_Val_Plot(history.history['acuracia'],history.history['val_acuracia'],
               history.history['loss'],history.history['val_loss'],
               history.history['auc'],history.history['val_auc'],
               history.history['precisão'],history.history['val_precisão'],
               history.history['f1_score'],history.history['val_f1_score']
              )

# %%
test_scores = vgg_model.evaluate(test_data, test_labels)

print("Accuracia = ", test_scores[1])
print("Precisão = ", test_scores[2])
print("Recall = ", test_scores[3])
print("AUC = ", test_scores[4])
print("F1_score = ", test_scores[5])
# Out:
# 40/40 [==============================] - 9s 221ms/step - loss: 1.2323 - acuracia: 0.7500 - precisão: 0.0000e+00 - recall: 0.0000e+00 - auc: 0.7452 - f1_score: 0.0000e+00
# Accuracia =  0.75
# Precisão =  0.0
# Recall =  0.0
# AUC =  0.7452090382575989
# F1_score =  0.0

# %%
pred_labels = vgg_model.predict(test_data)

# %%
kpred = vgg1.predict(vgg_model)

# %%
pred = kpred.tolist()
predictions = []
for i in pred:
  predictions.append(i.index(max(i)))

# %%
from sklearn.metrics import accuracy_score,classification_report,confusion_matrix

# %%
#Como os rótulos são arrays softmax, precisamos arredondar para tê-los na forma de 0s e 1s,
#semelhante aos test_labels
def roundoff(arr):
    arr[np.argwhere(arr != arr.max())] = 0
    arr[np.argwhere(arr == arr.max())] = 1
    return arr

for labels in pred_labels:
    labels = roundoff(labels)

print(classification_report(test_labels, pred_labels, target_names=CLASSES))

# %%
#Plotar a matriz de confusão para entender a classificação em detalhes

pred_ls = np.argmax(pred_labels, axis=1)
test_ls = np.argmax(test_labels, axis=1)

conf_arr = confusion_matrix(test_ls, pred_ls)

plt.figure(figsize=(8, 6), dpi=80, facecolor='w', edgecolor='k')

ax = sns.heatmap(conf_arr, cmap='Greens', annot=True, fmt='d', xticklabels= CLASSES,
                yticklabels=CLASSES)

plt.title('Diagnóstico da Doença de Alzheimer')
plt.xlabel('Predição')
plt.ylabel('Verdadeiro')
plt.show(ax)
